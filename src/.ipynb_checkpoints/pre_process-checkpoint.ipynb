# %%
import collections
import math
from operator import itemgetter
import pretty_midi

# %%
_SUSTAIN_ON = 0
_SUSTAIN_OFF = 1
_NOTE_ON = 2
_NOTE_OFF = 3

NOTE_ON = 1
NOTE_OFF = 2
TIME_SHIFT = 3
VELOCITY = 4

MAX_SHIFT_STEPS = 100

MIN_MIDI_VELOCITY = 1
MAX_MIDI_VELOCITY = 127

MIN_MIDI_PROGRAM = 0
MAX_MIDI_PROGRAM = 127
PROGRAMS_PER_FAMILY = 8

# %%
def resolve_pitch_clashes(sorted_notes):
    
    num_program_families = (MAX_MIDI_PROGRAM - MIN_MIDI_PROGRAM + 1) / \
    PROGRAMS_PER_FAMILY
    no_clash_notes = []
    active_pitch_notes = {}
    for program_family in range(num_program_families):
        active_pitch_notes[program_family + 1] = []

    for quantized_start, quantized_end, program, midi_note in sorted_notes:
        program_family = (program - MIN_MIDI_PROGRAM) // PROGRAMS_PER_FAMILY + 1
        new_active_pitch_notes = [(pitch, end) for pitch, end
          in active_pitch_notes[program_family] if end > quantized_start]
        active_pitch_notes[program_family] = new_active_pitch_notes
        note_pitch = midi_note.pitch
        max_end = 0
        for pitch, end in active_pitch_notes[program_family]:
            if pitch == note_pitch and end > max_end:
                max_end = end
            if max_end >= quantized_end:
                continue
        quantized_start = max(quantized_start, max_end)
        active_pitch_notes[program_family].append((note_pitch, quantized_end))
        no_clash_notes.append((quantized_start, quantized_end, program, midi_note))

    return no_clash_notes

# %%
def get_event_list(midi_notes, num_velocity_bins=32):
    
    no_drum_notes = [(quantized_start, quantized_end, program, midi_note)
                     for program, instrument, is_drum, quantized_start, quantized_end, midi_note
                     in midi_notes if not is_drum]
    sorted_no_drum_notes = sorted(no_drum_notes)
    no_clash_notes = resolve_pitch_clashes(sorted_no_drum_notes)

    note_on_set = []
    note_off_set = []
    for index, element in enumerate(no_clash_notes):
        quantized_start, quantized_end, program, midi_note = element
        note_on_set.append((quantized_start, index, program, False))
        note_off_set.append((quantized_end, index, program, True))
    note_events = sorted(note_on_set + note_off_set)

    velocity_bin_size = int(math.ceil(
        (MAX_MIDI_VELOCITY - MIN_MIDI_VELOCITY + 1) / num_velocity_bins))
    num_program_families = (MAX_MIDI_PROGRAM - MIN_MIDI_PROGRAM + 1) / \
    PROGRAMS_PER_FAMILY

    current_step = 0
    current_velocity_bin = {}
    
    for program_family in range(num_program_families):
        current_velocity_bin[program_family + 1] = 0
    events = []

    for step, index, program, is_off in note_events:
        if step > current_step:
            while step > current_step + MAX_SHIFT_STEPS:
                events.append((TIME_SHIFT, MAX_SHIFT_STEPS, 0))
                current_step += MAX_SHIFT_STEPS
            events.append((TIME_SHIFT, step-current_step, 0))
            current_step = step

        note_velocity = no_clash_notes[index][3].velocity
        note_pitch = no_clash_notes[index][3].pitch
        velocity_bin = (note_velocity - MIN_MIDI_VELOCITY) // velocity_bin_size + 1
        program_family = (program - MIN_MIDI_PROGRAM) // PROGRAMS_PER_FAMILY + 1
        if not is_off and velocity_bin != current_velocity_bin[program_family]:
            current_velocity_bin[program_family] = velocity_bin
            events.append((VELOCITY, velocity_bin, program_family))
        if not is_off:
            events.append((NOTE_ON, note_pitch, program_family))
        if is_off:
            events.append((NOTE_OFF, note_pitch, program_family))

    return events

# %%
def quantize_notes(midi_notes, steps_per_second=100):
    new_midi_notes = []

    for program, instrument, is_drum, midi_note in midi_notes:
        quantized_start = int(midi_note.start*steps_per_second + 0.5)
        quantized_end = int(midi_note.end*steps_per_second + 0.5)
        if quantized_start == quantized_end:
            quantized_end = quantized_end + 1
        new_midi_notes.append((program, instrument, is_drum, quantized_start,
                               quantized_end, midi_note))

    return new_midi_notes

# %%
def apply_sustain_control_changes(midi_notes, midi_control_changes,
                                  sustain_control_number=64):
    events = []
    events.extend([(midi_note.start, _NOTE_ON, instrument, midi_note) for
                   _1, instrument, _2, midi_note in midi_notes])
    events.extend([(midi_note.end, _NOTE_OFF, instrument, midi_note) for
                   _1, instrument, _2, midi_note in midi_notes])
    
    for _1, instrument, _2, control_change in midi_control_changes:
        if control_change.number != sustain_control_number:
            continue
        value = control_change.value
        if value >= 64:
            events.append((control_change.time, _SUSTAIN_ON, instrument,
                           control_change))
        if value < 64:
            events.append((control_change.time, _SUSTAIN_OFF, instrument,
                           control_change))

    events.sort(key=itemgetter(0))

    active_notes = collections.defaultdict(list)
    sus_active = collections.defaultdict(lambda: False)

    time = 0
    for time, event_type, instrument, event in events:
        if event_type == _SUSTAIN_ON:
            sus_active[instrument] = True
        elif event_type == _SUSTAIN_OFF:
            sus_active[instrument] = False
            new_active_notes = []
            for note in active_notes[instrument]:
                if note.end < time:
                    note.end = time
                else:
                    new_active_notes.append(note)
            active_notes[instrument] = new_active_notes
        elif event_type == _NOTE_ON:
            if sus_active[instrument]:
                new_active_notes = []
                for note in active_notes[instrument]:
                    if note.pitch == event.pitch:
                        note.end = time
                        if note.start == note.end:
                            midi_notes.remove(note)

                    else:
                        new_active_notes.append(note)
                active_notes[instrument] = new_active_notes
            active_notes[instrument].append(event)
    
        elif event_type == _NOTE_OFF:
            if sus_active[instrument]:
                pass
            else:
                if event in active_notes[instrument]:
                    active_notes[instrument].remove(event)

    for instrument in active_notes.values():
        for note in instrument:
            note.end = time

    return midi_notes, midi_control_changes

# %%
def get_control_changes(midi):
    midi_control_changes = []
    for num_instrument, midi_instrument in enumerate(midi.instruments):
        for midi_control_change in midi_instrument.control_changes:
            midi_control_changes.append((midi_instrument.program, num_instrument,
                                         midi_instrument.is_drum,
                                         midi_control_change))
    return midi_control_changes

# %%
#Function to get the notes from the midi object
#Each instrument in the midi file has a corresponding insturment number
#Each instruments has information regarding notes that are played by the intrument
#Each note has the information of start time, end time, pitch and veclocity
def get_notes(midi):
    midi_notes = []
    for num_instrument, midi_instrument in enumerate(midi.instruments):
        for midi_note in midi_instrument.notes:
            midi_notes.append((midi_instrument.program, num_instrument,
                               midi_instrument.is_drum, midi_note))
  
    return midi_notes

# %%
midi_file_path = '../data/Aerosmith/angel.mid'
midi = pretty_midi.PrettyMIDI(midi_file_path)

midi_notes = get_notes(midi)
midi_control_changes = get_control_changes(midi)
midi_notes, midi_control_changes = apply_sustain_control_changes(midi_notes,midi_control_changes)
midi_notes = quantize_notes(midi_notes)
events = get_event_list(midi_notes)

# %%
def get_notes_with_instrument_name(midi):
    midi_notes = []
    for num_instrument, midi_instrument in enumerate(midi.instruments):
        for midi_note in midi_instrument.notes:
            midi_notes.append((midi_instrument.program, num_instrument,
                               midi_instrument.is_drum, midi_note))
  
    return midi_notes
# Out:
# [(35,
#   0,
#   False,
#   774,
#   787,
#   Note(start=7.741932, end=7.870964, pitch=39, velocity=74)),
#  (35,
#   0,
#   False,
#   806,
#   870,
#   Note(start=8.064512, end=8.704297, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   871,
#   890,
#   Note(start=8.709673, end=8.903222, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   903,
#   919,
#   Note(start=9.032254, end=9.193544, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   935,
#   968,
#   Note(start=9.354834, end=9.677415, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   968,
#   1032,
#   Note(start=9.677415, end=10.322576, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   1032,
#   1045,
#   Note(start=10.322576, end=10.446232, pitch=44, velocity=80)),
#  (35,
#   0,
#   False,
#   1065,
#   1126,
#   Note(start=10.645156, end=11.258059, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   1129,
#   1138,
#   Note(start=11.290317, end=11.381715, pitch=43, velocity=78)),
#  (35,
#   0,
#   False,
#   1161,
#   1226,
#   Note(start=11.612898, end=12.258059, pitch=44, velocity=91)),
#  (35,
#   0,
#   False,
#   1226,
#   1242,
#   Note(start=12.258059, end=12.419349, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   1258,
#   1290,
#   Note(start=12.580639, end=12.903220, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   1290,
#   1303,
#   Note(start=12.903220, end=13.026876, pitch=39, velocity=80)),
#  (35,
#   0,
#   False,
#   1323,
#   1384,
#   Note(start=13.225800, end=13.838703, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   1387,
#   1396,
#   Note(start=13.870961, end=13.962359, pitch=38, velocity=78)),
#  (35,
#   0,
#   False,
#   1419,
#   1484,
#   Note(start=14.193542, end=14.838703, pitch=39, velocity=91)),
#  (35,
#   0,
#   False,
#   1484,
#   1548,
#   Note(start=14.838703, end=15.483864, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   1548,
#   1559,
#   Note(start=15.483864, end=15.586014, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   1581,
#   1637,
#   Note(start=15.806444, end=16.370960, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   1645,
#   1654,
#   Note(start=16.451605, end=16.537627, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   1677,
#   1742,
#   Note(start=16.774186, end=17.419347, pitch=44, velocity=91)),
#  (35,
#   0,
#   False,
#   1742,
#   1758,
#   Note(start=17.419347, end=17.580637, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   1774,
#   1806,
#   Note(start=17.741927, end=18.064508, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   1806,
#   1819,
#   Note(start=18.064508, end=18.193540, pitch=39, velocity=74)),
#  (35,
#   0,
#   False,
#   1839,
#   1903,
#   Note(start=18.387088, end=19.026873, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   1903,
#   1923,
#   Note(start=19.032249, end=19.225798, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   1935,
#   2000,
#   Note(start=19.354830, end=19.999991, pitch=39, velocity=91)),
#  (35,
#   0,
#   False,
#   2000,
#   2016,
#   Note(start=19.999991, end=20.161281, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   2032,
#   2065,
#   Note(start=20.322571, end=20.645152, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   2065,
#   2075,
#   Note(start=20.645152, end=20.747302, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   2097,
#   2153,
#   Note(start=20.967732, end=21.532248, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   2161,
#   2170,
#   Note(start=21.612893, end=21.698915, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   2194,
#   2210,
#   Note(start=21.935474, end=22.096764, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   2226,
#   2258,
#   Note(start=22.258054, end=22.580635, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   2258,
#   2323,
#   Note(start=22.580635, end=23.225796, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   2323,
#   2333,
#   Note(start=23.225796, end=23.327946, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   2355,
#   2411,
#   Note(start=23.548376, end=24.112892, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   2419,
#   2428,
#   Note(start=24.193537, end=24.279559, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   2452,
#   2516,
#   Note(start=24.516118, end=25.161279, pitch=36, velocity=91)),
#  (35,
#   0,
#   False,
#   2516,
#   2581,
#   Note(start=25.161279, end=25.806440, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   2581,
#   2674,
#   Note(start=25.806440, end=26.736547, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   2677,
#   2714,
#   Note(start=26.774181, end=27.139773, pitch=39, velocity=80)),
#  (35,
#   0,
#   False,
#   2710,
#   2723,
#   Note(start=27.096762, end=27.225794, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   2742,
#   2795,
#   Note(start=27.419342, end=27.946224, pitch=44, velocity=89)),
#  (35,
#   0,
#   False,
#   2806,
#   2817,
#   Note(start=28.064503, end=28.166654, pitch=44, velocity=76)),
#  (35,
#   0,
#   False,
#   2839,
#   2851,
#   Note(start=28.387084, end=28.510740, pitch=44, velocity=80)),
#  (35,
#   0,
#   False,
#   2871,
#   2932,
#   Note(start=28.709664, end=29.322567, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   2935,
#   2945,
#   Note(start=29.354825, end=29.446223, pitch=43, velocity=78)),
#  (35,
#   0,
#   False,
#   2968,
#   2978,
#   Note(start=29.677406, end=29.779556, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   3000,
#   3056,
#   Note(start=29.999986, end=30.564502, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   3065,
#   3073,
#   Note(start=30.645147, end=30.731169, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   3097,
#   3112,
#   Note(start=30.973104, end=31.118266, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   3129,
#   3181,
#   Note(start=31.290308, end=31.811814, pitch=39, velocity=100)),
#  (35,
#   0,
#   False,
#   3193,
#   3204,
#   Note(start=31.930093, end=32.037620, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   3224,
#   3237,
#   Note(start=32.236545, end=32.370953, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   3257,
#   3311,
#   Note(start=32.569878, end=33.107512, pitch=39, velocity=98)),
#  (35,
#   0,
#   False,
#   3323,
#   3344,
#   Note(start=33.225791, end=33.440845, pitch=39, velocity=60)),
#  (35,
#   0,
#   False,
#   3354,
#   3374,
#   Note(start=33.537619, end=33.736544, pitch=39, velocity=78)),
#  (35,
#   0,
#   False,
#   3385,
#   3440,
#   Note(start=33.854823, end=34.403210, pitch=39, velocity=102)),
#  (35,
#   0,
#   False,
#   3452,
#   3476,
#   Note(start=34.516113, end=34.758049, pitch=39, velocity=89)),
#  (35,
#   0,
#   False,
#   3483,
#   3498,
#   Note(start=34.833318, end=34.983855, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   3517,
#   3571,
#   Note(start=35.172027, end=35.709661, pitch=39, velocity=100)),
#  (35,
#   0,
#   False,
#   3582,
#   3605,
#   Note(start=35.822565, end=36.053747, pitch=39, velocity=100)),
#  (35,
#   0,
#   False,
#   3613,
#   3696,
#   Note(start=36.129016, end=36.962349, pitch=44, velocity=80)),
#  (35,
#   0,
#   False,
#   3710,
#   3722,
#   Note(start=37.096757, end=37.220413, pitch=44, velocity=63)),
#  (35,
#   0,
#   False,
#   3742,
#   3757,
#   Note(start=37.419338, end=37.569876, pitch=44, velocity=70)),
#  (35,
#   0,
#   False,
#   3774,
#   3803,
#   Note(start=37.741918, end=38.026865, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   3806,
#   3825,
#   Note(start=38.064499, end=38.247295, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   3839,
#   3851,
#   Note(start=38.387079, end=38.505359, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   3871,
#   3884,
#   Note(start=38.709660, end=38.838692, pitch=44, velocity=74)),
#  (35,
#   0,
#   False,
#   3903,
#   3967,
#   Note(start=39.032240, end=39.672025, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   3968,
#   3987,
#   Note(start=39.677401, end=39.870950, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   4000,
#   4012,
#   Note(start=39.999982, end=40.118262, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   4032,
#   4095,
#   Note(start=40.322562, end=40.951594, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   4097,
#   4112,
#   Note(start=40.967723, end=41.118261, pitch=32, velocity=82)),
#  (35,
#   0,
#   False,
#   4129,
#   4204,
#   Note(start=41.290304, end=42.042992, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   4226,
#   4236,
#   Note(start=42.258045, end=42.360196, pitch=39, velocity=72)),
#  (35,
#   0,
#   False,
#   4258,
#   4270,
#   Note(start=42.580626, end=42.704282, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   4290,
#   4334,
#   Note(start=42.903206, end=43.338690, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   4355,
#   4378,
#   Note(start=43.548367, end=43.779550, pitch=39, velocity=98)),
#  (35,
#   0,
#   False,
#   4387,
#   4400,
#   Note(start=43.870948, end=43.999980, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   4419,
#   4471,
#   Note(start=44.193528, end=44.709657, pitch=36, velocity=68)),
#  (35,
#   0,
#   False,
#   4484,
#   4496,
#   Note(start=44.838689, end=44.962345, pitch=36, velocity=85)),
#  (35,
#   0,
#   False,
#   4516,
#   4529,
#   Note(start=45.161270, end=45.290302, pitch=36, velocity=60)),
#  (35,
#   0,
#   False,
#   4548,
#   4588,
#   Note(start=45.483850, end=45.876323, pitch=36, velocity=85)),
#  (35,
#   0,
#   False,
#   4613,
#   4623,
#   Note(start=46.129011, end=46.225786, pitch=42, velocity=91)),
#  (35,
#   0,
#   False,
#   4645,
#   4656,
#   Note(start=46.451592, end=46.564495, pitch=43, velocity=61)),
#  (35,
#   0,
#   False,
#   4677,
#   4745,
#   Note(start=46.774172, end=47.451592, pitch=43, velocity=95)),
#  (35,
#   0,
#   False,
#   4742,
#   4771,
#   Note(start=47.419333, end=47.709656, pitch=38, velocity=85)),
#  (35,
#   0,
#   False,
#   4774,
#   4785,
#   Note(start=47.741914, end=47.849441, pitch=43, velocity=102)),
#  (35,
#   0,
#   False,
#   4806,
#   4862,
#   Note(start=48.064494, end=48.618258, pitch=43, velocity=100)),
#  (35,
#   0,
#   False,
#   4871,
#   4878,
#   Note(start=48.709655, end=48.784924, pitch=43, velocity=87)),
#  (35,
#   0,
#   False,
#   4903,
#   4916,
#   Note(start=49.032236, end=49.161268, pitch=44, velocity=78)),
#  (35,
#   0,
#   False,
#   4935,
#   4993,
#   Note(start=49.354816, end=49.930085, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   5000,
#   5015,
#   Note(start=49.999977, end=50.145139, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   5032,
#   5054,
#   Note(start=50.322558, end=50.542988, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   5065,
#   5074,
#   Note(start=50.645138, end=50.741913, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   5097,
#   5105,
#   Note(start=50.967719, end=51.053740, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   5129,
#   5139,
#   Note(start=51.290299, end=51.392450, pitch=44, velocity=95)),
#  (35,
#   0,
#   False,
#   5161,
#   5174,
#   Note(start=51.612880, end=51.741912, pitch=34, velocity=74)),
#  (35,
#   0,
#   False,
#   5194,
#   5258,
#   Note(start=51.935460, end=52.575245, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   5258,
#   5277,
#   Note(start=52.580621, end=52.774170, pitch=29, velocity=85)),
#  (35,
#   0,
#   False,
#   5290,
#   5303,
#   Note(start=52.903202, end=53.026858, pitch=36, velocity=80)),
#  (35,
#   0,
#   False,
#   5323,
#   5384,
#   Note(start=53.225782, end=53.838685, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   5387,
#   5396,
#   Note(start=53.870943, end=53.962341, pitch=43, velocity=78)),
#  (35,
#   0,
#   False,
#   5419,
#   5432,
#   Note(start=54.193524, end=54.322556, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   5452,
#   5503,
#   Note(start=54.516104, end=55.032233, pitch=44, velocity=68)),
#  (35,
#   0,
#   False,
#   5516,
#   5528,
#   Note(start=55.161265, end=55.284921, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   5548,
#   5561,
#   Note(start=55.483846, end=55.612878, pitch=44, velocity=60)),
#  (35,
#   0,
#   False,
#   5581,
#   5620,
#   Note(start=55.806426, end=56.198899, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   5645,
#   5655,
#   Note(start=56.451587, end=56.548362, pitch=33, velocity=91)),
#  (35,
#   0,
#   False,
#   5677,
#   5690,
#   Note(start=56.774168, end=56.903200, pitch=34, velocity=74)),
#  (35,
#   0,
#   False,
#   5710,
#   5774,
#   Note(start=57.096748, end=57.736533, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   5774,
#   5794,
#   Note(start=57.741909, end=57.935458, pitch=29, velocity=85)),
#  (35,
#   0,
#   False,
#   5806,
#   5818,
#   Note(start=58.064490, end=58.182770, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   5839,
#   5902,
#   Note(start=58.387070, end=59.016102, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   5903,
#   5918,
#   Note(start=59.032231, end=59.182769, pitch=24, velocity=82)),
#  (35,
#   0,
#   False,
#   5935,
#   5948,
#   Note(start=59.354812, end=59.483844, pitch=44, velocity=78)),
#  (35,
#   0,
#   False,
#   5968,
#   6025,
#   Note(start=59.677392, end=60.252661, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   6032,
#   6047,
#   Note(start=60.322553, end=60.467715, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   6065,
#   6087,
#   Note(start=60.645134, end=60.865564, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   6097,
#   6106,
#   Note(start=60.967714, end=61.064489, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   6129,
#   6138,
#   Note(start=61.290295, end=61.376316, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   6161,
#   6172,
#   Note(start=61.612875, end=61.715026, pitch=44, velocity=95)),
#  (35,
#   0,
#   False,
#   6194,
#   6206,
#   Note(start=61.935456, end=62.059112, pitch=34, velocity=80)),
#  (35,
#   0,
#   False,
#   6226,
#   6287,
#   Note(start=62.258036, end=62.870939, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   6290,
#   6299,
#   Note(start=62.903197, end=62.994595, pitch=35, velocity=78)),
#  (35,
#   0,
#   False,
#   6323,
#   6334,
#   Note(start=63.225778, end=63.344058, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   6355,
#   6418,
#   Note(start=63.548358, end=64.177390, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   6419,
#   6434,
#   Note(start=64.193519, end=64.344057, pitch=24, velocity=82)),
#  (35,
#   0,
#   False,
#   6452,
#   6465,
#   Note(start=64.516100, end=64.645132, pitch=44, velocity=78)),
#  (35,
#   0,
#   False,
#   6484,
#   6541,
#   Note(start=64.838680, end=65.413949, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   6548,
#   6563,
#   Note(start=65.483841, end=65.629003, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   6581,
#   6603,
#   Note(start=65.806422, end=66.026852, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   6613,
#   6623,
#   Note(start=66.129002, end=66.225777, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   6645,
#   6654,
#   Note(start=66.451583, end=66.537604, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   6677,
#   6688,
#   Note(start=66.774163, end=66.876314, pitch=44, velocity=95)),
#  (35,
#   0,
#   False,
#   6710,
#   6731,
#   Note(start=67.096744, end=67.306421, pitch=34, velocity=76)),
#  (35,
#   0,
#   False,
#   6742,
#   6795,
#   Note(start=67.419324, end=67.951582, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   6806,
#   6819,
#   Note(start=68.064485, end=68.188141, pitch=34, velocity=95)),
#  (35,
#   0,
#   False,
#   6839,
#   6854,
#   Note(start=68.387066, end=68.542980, pitch=34, velocity=95)),
#  (35,
#   0,
#   False,
#   6871,
#   6923,
#   Note(start=68.709646, end=69.231152, pitch=34, velocity=102)),
#  (35,
#   0,
#   False,
#   6935,
#   6948,
#   Note(start=69.354807, end=69.483840, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   6968,
#   6983,
#   Note(start=69.677388, end=69.833302, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   7000,
#   7048,
#   Note(start=69.999968, end=70.483839, pitch=34, velocity=89)),
#  (35,
#   0,
#   False,
#   7065,
#   7078,
#   Note(start=70.645129, end=70.779538, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   7097,
#   7111,
#   Note(start=70.967710, end=71.112871, pitch=34, velocity=100)),
#  (35,
#   0,
#   False,
#   7129,
#   7178,
#   Note(start=71.290290, end=71.784914, pitch=34, velocity=102)),
#  (35,
#   0,
#   False,
#   7194,
#   7205,
#   Note(start=71.935451, end=72.053731, pitch=34, velocity=100)),
#  (35,
#   0,
#   False,
#   7226,
#   7236,
#   Note(start=72.258032, end=72.360182, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   7258,
#   7315,
#   Note(start=72.580612, end=73.145128, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   7323,
#   7331,
#   Note(start=73.225773, end=73.311795, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   7355,
#   7419,
#   Note(start=73.548354, end=74.193515, pitch=39, velocity=91)),
#  (35,
#   0,
#   False,
#   7419,
#   7435,
#   Note(start=74.193515, end=74.354805, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   7452,
#   7484,
#   Note(start=74.516095, end=74.838676, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   7484,
#   7497,
#   Note(start=74.838676, end=74.967708, pitch=44, velocity=74)),
#  (35,
#   0,
#   False,
#   7516,
#   7580,
#   Note(start=75.161256, end=75.801041, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   7581,
#   7600,
#   Note(start=75.806417, end=75.999966, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   7613,
#   7677,
#   Note(start=76.128998, end=76.774159, pitch=44, velocity=91)),
#  (35,
#   0,
#   False,
#   7677,
#   7694,
#   Note(start=76.774159, end=76.935449, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   7710,
#   7742,
#   Note(start=77.096739, end=77.419320, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   7742,
#   7754,
#   Note(start=77.419320, end=77.537600, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   7774,
#   7837,
#   Note(start=77.741900, end=78.370932, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   7839,
#   7854,
#   Note(start=78.387061, end=78.537599, pitch=24, velocity=82)),
#  (35,
#   0,
#   False,
#   7871,
#   7887,
#   Note(start=78.709642, end=78.870932, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   7903,
#   7935,
#   Note(start=79.032222, end=79.354803, pitch=36, velocity=85)),
#  (35,
#   0,
#   False,
#   7935,
#   7952,
#   Note(start=79.354803, end=79.516093, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   7968,
#   8000,
#   Note(start=79.677383, end=79.999964, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   8000,
#   8010,
#   Note(start=79.999964, end=80.102114, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   8032,
#   8089,
#   Note(start=80.322544, end=80.887060, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   8097,
#   8105,
#   Note(start=80.967705, end=81.053727, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   8129,
#   8194,
#   Note(start=81.290286, end=81.935447, pitch=44, velocity=91)),
#  (35,
#   0,
#   False,
#   8194,
#   8210,
#   Note(start=81.935447, end=82.096737, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   8226,
#   8258,
#   Note(start=82.258027, end=82.580608, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   8258,
#   8268,
#   Note(start=82.580608, end=82.682758, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   8290,
#   8347,
#   Note(start=82.903188, end=83.467704, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   8355,
#   8363,
#   Note(start=83.548349, end=83.634371, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   8387,
#   8452,
#   Note(start=83.870930, end=84.516091, pitch=39, velocity=91)),
#  (35,
#   0,
#   False,
#   8452,
#   8468,
#   Note(start=84.516091, end=84.677381, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   8484,
#   8516,
#   Note(start=84.838671, end=85.161252, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   8516,
#   8526,
#   Note(start=85.161252, end=85.263402, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   8548,
#   8605,
#   Note(start=85.483832, end=86.048348, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   8613,
#   8622,
#   Note(start=86.128993, end=86.215015, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   8645,
#   8661,
#   Note(start=86.451574, end=86.612864, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   8677,
#   8710,
#   Note(start=86.774154, end=87.096735, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   8710,
#   8774,
#   Note(start=87.096735, end=87.741896, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   8774,
#   8852,
#   Note(start=87.741896, end=88.516089, pitch=36, velocity=89)),
#  (35,
#   0,
#   False,
#   8871,
#   8881,
#   Note(start=88.709637, end=88.811788, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   8903,
#   8918,
#   Note(start=89.032218, end=89.182756, pitch=36, velocity=98)),
#  (35,
#   0,
#   False,
#   8935,
#   8980,
#   Note(start=89.354798, end=89.795659, pitch=36, velocity=105)),
#  (35,
#   0,
#   False,
#   9032,
#   9116,
#   Note(start=90.322540, end=91.155873, pitch=44, velocity=80)),
#  (35,
#   0,
#   False,
#   9129,
#   9141,
#   Note(start=91.290281, end=91.413937, pitch=44, velocity=63)),
#  (35,
#   0,
#   False,
#   9161,
#   9176,
#   Note(start=91.612862, end=91.763400, pitch=44, velocity=70)),
#  (35,
#   0,
#   False,
#   9194,
#   9222,
#   Note(start=91.935442, end=92.220389, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   9226,
#   9244,
#   Note(start=92.258023, end=92.440819, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   9258,
#   9270,
#   Note(start=92.580603, end=92.698883, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   9290,
#   9303,
#   Note(start=92.903184, end=93.032216, pitch=44, velocity=74)),
#  (35,
#   0,
#   False,
#   9323,
#   9387,
#   Note(start=93.225764, end=93.865549, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   9387,
#   9406,
#   Note(start=93.870925, end=94.064474, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   9419,
#   9432,
#   Note(start=94.193506, end=94.317162, pitch=44, velocity=80)),
#  (35,
#   0,
#   False,
#   9452,
#   9513,
#   Note(start=94.516086, end=95.128989, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   9516,
#   9525,
#   Note(start=95.161247, end=95.252645, pitch=38, velocity=78)),
#  (35,
#   0,
#   False,
#   9548,
#   9562,
#   Note(start=95.483828, end=95.623613, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   9581,
#   9644,
#   Note(start=95.806408, end=96.440817, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   9645,
#   9680,
#   Note(start=96.451569, end=96.801032, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   9677,
#   9691,
#   Note(start=96.774150, end=96.913935, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   9710,
#   9759,
#   Note(start=97.096730, end=97.585978, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   9774,
#   9784,
#   Note(start=97.741891, end=97.838666, pitch=39, velocity=80)),
#  (35,
#   0,
#   False,
#   9806,
#   9819,
#   Note(start=98.064472, end=98.188128, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   9839,
#   9889,
#   Note(start=98.387052, end=98.892429, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   9903,
#   9913,
#   Note(start=99.032213, end=99.134364, pitch=39, velocity=61)),
#  (35,
#   0,
#   False,
#   9935,
#   9951,
#   Note(start=99.354794, end=99.505332, pitch=39, velocity=70)),
#  (35,
#   0,
#   False,
#   9968,
#   10024,
#   Note(start=99.677374, end=100.241890, pitch=39, velocity=95)),
#  (35,
#   0,
#   False,
#   10032,
#   10040,
#   Note(start=100.322535, end=100.397804, pitch=43, velocity=80)),
#  (35,
#   0,
#   False,
#   10065,
#   10140,
#   Note(start=100.645116, end=101.397804, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   10161,
#   10172,
#   Note(start=101.612857, end=101.715008, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   10194,
#   10206,
#   Note(start=101.935438, end=102.059094, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   10226,
#   10269,
#   Note(start=102.258018, end=102.693502, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   10290,
#   10313,
#   Note(start=102.903179, end=103.134362, pitch=44, velocity=98)),
#  (35,
#   0,
#   False,
#   10323,
#   10333,
#   Note(start=103.225760, end=103.327910, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   10355,
#   10411,
#   Note(start=103.548340, end=104.112856, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   10419,
#   10428,
#   Note(start=104.193501, end=104.279523, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   10452,
#   10463,
#   Note(start=104.516082, end=104.634362, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   10484,
#   10547,
#   Note(start=104.838662, end=105.467694, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   10548,
#   10563,
#   Note(start=105.483823, end=105.634361, pitch=32, velocity=82)),
#  (35,
#   0,
#   False,
#   10581,
#   10666,
#   Note(start=105.806404, end=106.661242, pitch=39, velocity=89)),
#  (35,
#   0,
#   False,
#   10677,
#   10689,
#   Note(start=106.774145, end=106.887049, pitch=39, velocity=76)),
#  (35,
#   0,
#   False,
#   10710,
#   10723,
#   Note(start=107.096726, end=107.225758, pitch=39, velocity=70)),
#  (35,
#   0,
#   False,
#   10742,
#   10797,
#   Note(start=107.419306, end=107.973070, pitch=39, velocity=100)),
#  (35,
#   0,
#   False,
#   10806,
#   10839,
#   Note(start=108.064467, end=108.387048, pitch=39, velocity=89)),
#  (35,
#   0,
#   False,
#   10839,
#   10924,
#   Note(start=108.387048, end=109.241886, pitch=36, velocity=89)),
#  (35,
#   0,
#   False,
#   10935,
#   10947,
#   Note(start=109.354789, end=109.467693, pitch=36, velocity=76)),
#  (35,
#   0,
#   False,
#   10968,
#   10981,
#   Note(start=109.677370, end=109.806402, pitch=36, velocity=70)),
#  (35,
#   0,
#   False,
#   11000,
#   11055,
#   Note(start=109.999950, end=110.553714, pitch=36, velocity=100)),
#  (35,
#   0,
#   False,
#   11065,
#   11097,
#   Note(start=110.645111, end=110.967692, pitch=36, velocity=89)),
#  (35,
#   0,
#   False,
#   11097,
#   11174,
#   Note(start=110.967692, end=111.741885, pitch=43, velocity=89)),
#  (35,
#   0,
#   False,
#   11194,
#   11204,
#   Note(start=111.935433, end=112.037584, pitch=43, velocity=87)),
#  (35,
#   0,
#   False,
#   11226,
#   11241,
#   Note(start=112.258014, end=112.408552, pitch=43, velocity=98)),
#  (35,
#   0,
#   False,
#   11258,
#   11302,
#   Note(start=112.580594, end=113.021455, pitch=43, velocity=105)),
#  (35,
#   0,
#   False,
#   11355,
#   11430,
#   Note(start=113.548336, end=114.301024, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   11452,
#   11462,
#   Note(start=114.516077, end=114.618228, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   11484,
#   11496,
#   Note(start=114.838658, end=114.962314, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   11516,
#   11560,
#   Note(start=115.161238, end=115.596722, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   11581,
#   11604,
#   Note(start=115.806399, end=116.037582, pitch=44, velocity=98)),
#  (35,
#   0,
#   False,
#   11613,
#   11625,
#   Note(start=116.128980, end=116.247260, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   11645,
#   11708,
#   Note(start=116.451560, end=117.080592, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   11710,
#   11725,
#   Note(start=117.096721, end=117.247259, pitch=22, velocity=82)),
#  (35,
#   0,
#   False,
#   11742,
#   11754,
#   Note(start=117.419302, end=117.542958, pitch=36, velocity=80)),
#  (35,
#   0,
#   False,
#   11774,
#   11835,
#   Note(start=117.741882, end=118.354785, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   11839,
#   11848,
#   Note(start=118.387043, end=118.478441, pitch=43, velocity=78)),
#  (35,
#   0,
#   False,
#   11871,
#   11964,
#   Note(start=118.709624, end=119.639731, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   11968,
#   12004,
#   Note(start=119.677365, end=120.042957, pitch=39, velocity=80)),
#  (35,
#   0,
#   False,
#   12000,
#   12013,
#   Note(start=119.999946, end=120.128978, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   12032,
#   12085,
#   Note(start=120.322526, end=120.849408, pitch=44, velocity=89)),
#  (35,
#   0,
#   False,
#   12097,
#   12107,
#   Note(start=120.967687, end=121.069838, pitch=44, velocity=76)),
#  (35,
#   0,
#   False,
#   12129,
#   12141,
#   Note(start=121.290268, end=121.413924, pitch=34, velocity=80)),
#  (35,
#   0,
#   False,
#   12161,
#   12223,
#   Note(start=121.612848, end=122.225751, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   12226,
#   12235,
#   Note(start=122.258009, end=122.349407, pitch=35, velocity=78)),
#  (35,
#   0,
#   False,
#   12258,
#   12270,
#   Note(start=122.580590, end=122.698870, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   12290,
#   12353,
#   Note(start=122.903170, end=123.532202, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   12355,
#   12370,
#   Note(start=123.548331, end=123.698869, pitch=24, velocity=82)),
#  (35,
#   0,
#   False,
#   12387,
#   12462,
#   Note(start=123.870912, end=124.623600, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   12484,
#   12494,
#   Note(start=124.838653, end=124.940804, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   12516,
#   12528,
#   Note(start=125.161234, end=125.284890, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   12548,
#   12592,
#   Note(start=125.483814, end=125.919298, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   12613,
#   12636,
#   Note(start=126.128975, end=126.360158, pitch=44, velocity=98)),
#  (35,
#   0,
#   False,
#   12645,
#   12655,
#   Note(start=126.451556, end=126.553706, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   12677,
#   12734,
#   Note(start=126.774136, end=127.338652, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   12742,
#   12751,
#   Note(start=127.419297, end=127.505319, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   12774,
#   12786,
#   Note(start=127.741878, end=127.860158, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   12806,
#   12869,
#   Note(start=128.064458, end=128.693490, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   12871,
#   12886,
#   Note(start=128.709619, end=128.860157, pitch=24, velocity=82)),
#  (35,
#   0,
#   False,
#   12903,
#   12978,
#   Note(start=129.032200, end=129.784888, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   13000,
#   13010,
#   Note(start=129.999941, end=130.102092, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   13032,
#   13045,
#   Note(start=130.322522, end=130.446178, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   13065,
#   13108,
#   Note(start=130.645102, end=131.080586, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   13129,
#   13152,
#   Note(start=131.290263, end=131.521446, pitch=44, velocity=98)),
#  (35,
#   0,
#   False,
#   13161,
#   13175,
#   Note(start=131.612844, end=131.752629, pitch=34, velocity=89)),
#  (35,
#   0,
#   False,
#   13194,
#   13247,
#   Note(start=131.935424, end=132.473059, pitch=34, velocity=95)),
#  (35,
#   0,
#   False,
#   13258,
#   13281,
#   Note(start=132.580585, end=132.806392, pitch=34, velocity=89)),
#  (35,
#   0,
#   False,
#   13290,
#   13306,
#   Note(start=132.903166, end=133.064456, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   13323,
#   13371,
#   Note(start=133.225746, end=133.714994, pitch=34, velocity=93)),
#  (35,
#   0,
#   False,
#   13387,
#   13404,
#   Note(start=133.870907, end=134.037574, pitch=34, velocity=95)),
#  (35,
#   0,
#   False,
#   13419,
#   13434,
#   Note(start=134.193488, end=134.344026, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   13452,
#   13505,
#   Note(start=134.516068, end=135.053703, pitch=34, velocity=102)),
#  (35,
#   0,
#   False,
#   13516,
#   13538,
#   Note(start=135.161229, end=135.376283, pitch=34, velocity=89)),
#  (35,
#   0,
#   False,
#   13548,
#   13574,
#   Note(start=135.483810, end=135.736498, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   13581,
#   13597,
#   Note(start=135.806390, end=135.973057, pitch=34, velocity=72)),
#  (35,
#   0,
#   False,
#   13613,
#   13626,
#   Note(start=136.128971, end=136.258003, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   13645,
#   13653,
#   Note(start=136.451551, end=136.532197, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   13677,
#   13688,
#   Note(start=136.774132, end=136.876282, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   13710,
#   13766,
#   Note(start=137.096712, end=137.661228, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   13774,
#   13783,
#   Note(start=137.741873, end=137.827895, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   13806,
#   13823,
#   Note(start=138.064454, end=138.225744, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   13839,
#   13871,
#   Note(start=138.387034, end=138.709615, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   13871,
#   13887,
#   Note(start=138.709615, end=138.870905, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   13903,
#   13935,
#   Note(start=139.032195, end=139.354776, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   13935,
#   13947,
#   Note(start=139.354776, end=139.473056, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   13968,
#   14031,
#   Note(start=139.677356, end=140.306388, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   14032,
#   14047,
#   Note(start=140.322517, end=140.473055, pitch=32, velocity=82)),
#  (35,
#   0,
#   False,
#   14065,
#   14129,
#   Note(start=140.645098, end=141.290259, pitch=44, velocity=91)),
#  (35,
#   0,
#   False,
#   14129,
#   14194,
#   Note(start=141.290259, end=141.935420, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   14194,
#   14204,
#   Note(start=141.935420, end=142.037570, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   14226,
#   14282,
#   Note(start=142.258000, end=142.822516, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   14290,
#   14299,
#   Note(start=142.903161, end=142.989183, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   14323,
#   14387,
#   Note(start=143.225742, end=143.870903, pitch=36, velocity=91)),
#  (35,
#   0,
#   False,
#   14387,
#   14452,
#   Note(start=143.870903, end=144.516064, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   14452,
#   14463,
#   Note(start=144.516064, end=144.634344, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   14484,
#   14547,
#   Note(start=144.838644, end=145.467676, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   14548,
#   14563,
#   Note(start=145.483805, end=145.634343, pitch=32, velocity=82)),
#  (35,
#   0,
#   False,
#   14581,
#   14597,
#   Note(start=145.806386, end=145.967676, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   14613,
#   14645,
#   Note(start=146.128966, end=146.451547, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   14645,
#   14661,
#   Note(start=146.451547, end=146.612837, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   14677,
#   14710,
#   Note(start=146.774127, end=147.096708, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   14710,
#   14721,
#   Note(start=147.096708, end=147.214988, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   14742,
#   14805,
#   Note(start=147.419288, end=148.048320, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   14806,
#   14821,
#   Note(start=148.064449, end=148.214987, pitch=27, velocity=82)),
#  (35,
#   0,
#   False,
#   14839,
#   14855,
#   Note(start=148.387030, end=148.548320, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   14871,
#   14903,
#   Note(start=148.709610, end=149.032191, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   14903,
#   14968,
#   Note(start=149.032191, end=149.677352, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   14968,
#   14980,
#   Note(start=149.677352, end=149.795632, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   15000,
#   15063,
#   Note(start=149.999932, end=150.628964, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   15065,
#   15080,
#   Note(start=150.645093, end=150.795631, pitch=32, velocity=82)),
#  (35,
#   0,
#   False,
#   15097,
#   15113,
#   Note(start=150.967674, end=151.128964, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   15129,
#   15161,
#   Note(start=151.290254, end=151.612835, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   15161,
#   15177,
#   Note(start=151.612835, end=151.774125, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   15194,
#   15226,
#   Note(start=151.935415, end=152.257996, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   15226,
#   15236,
#   Note(start=152.257996, end=152.360146, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   15258,
#   15315,
#   Note(start=152.580576, end=153.145092, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   15323,
#   15331,
#   Note(start=153.225737, end=153.311759, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   15355,
#   15419,
#   Note(start=153.548318, end=154.193479, pitch=36, velocity=91)),
#  (35,
#   0,
#   False,
#   15419,
#   15484,
#   Note(start=154.193479, end=154.838640, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   15484,
#   15497,
#   Note(start=154.838640, end=154.967672, pitch=44, velocity=74)),
#  (35,
#   0,
#   False,
#   15516,
#   15580,
#   Note(start=155.161220, end=155.801005, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   15581,
#   15600,
#   Note(start=155.806381, end=155.999930, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   15613,
#   15677,
#   Note(start=156.128962, end=156.774123, pitch=44, velocity=91)),
#  (35,
#   0,
#   False,
#   15677,
#   15694,
#   Note(start=156.774123, end=156.935413, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   15710,
#   15742,
#   Note(start=157.096703, end=157.419284, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   15742,
#   15752,
#   Note(start=157.419284, end=157.521434, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   15774,
#   15831,
#   Note(start=157.741864, end=158.306380, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   15839,
#   15847,
#   Note(start=158.387025, end=158.473047, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   15871,
#   15935,
#   Note(start=158.709606, end=159.354767, pitch=39, velocity=91)),
#  (35,
#   0,
#   False,
#   15935,
#   16000,
#   Note(start=159.354767, end=159.999928, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   16000,
#   16013,
#   Note(start=159.999928, end=160.128960, pitch=44, velocity=74)),
#  (35,
#   0,
#   False,
#   16032,
#   16096,
#   Note(start=160.322508, end=160.962293, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   16097,
#   16116,
#   Note(start=160.967669, end=161.161218, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   16129,
#   16194,
#   Note(start=161.290250, end=161.935411, pitch=44, velocity=91)),
#  (35,
#   0,
#   False,
#   16194,
#   16210,
#   Note(start=161.935411, end=162.096701, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   16226,
#   16258,
#   Note(start=162.257991, end=162.580572, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   16258,
#   16270,
#   Note(start=162.580572, end=162.698852, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   16290,
#   16353,
#   Note(start=162.903152, end=163.532184, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   16355,
#   16370,
#   Note(start=163.548313, end=163.698851, pitch=24, velocity=82)),
#  (35,
#   0,
#   False,
#   16387,
#   16452,
#   Note(start=163.870894, end=164.516055, pitch=36, velocity=91)),
#  (35,
#   0,
#   False,
#   16452,
#   16468,
#   Note(start=164.516055, end=164.677345, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   16484,
#   16516,
#   Note(start=164.838635, end=165.161216, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   16516,
#   16529,
#   Note(start=165.161216, end=165.290248, pitch=44, velocity=78)),
#  (35,
#   0,
#   False,
#   16548,
#   16606,
#   Note(start=165.483796, end=166.059065, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   16613,
#   16627,
#   Note(start=166.128957, end=166.274119, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   16645,
#   16667,
#   Note(start=166.451538, end=166.671968, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   16677,
#   16687,
#   Note(start=166.774118, end=166.870893, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   16710,
#   16718,
#   Note(start=167.096699, end=167.182720, pitch=44, velocity=72)),
#  (35,
#   0,
#   False,
#   16742,
#   16752,
#   Note(start=167.419279, end=167.521430, pitch=44, velocity=95)),
#  (35,
#   0,
#   False,
#   16774,
#   16867,
#   Note(start=167.741860, end=168.671967, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   16871,
#   16908,
#   Note(start=168.709601, end=169.075193, pitch=29, velocity=80)),
#  (35,
#   0,
#   False,
#   16903,
#   16916,
#   Note(start=169.032182, end=169.161214, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   16935,
#   16988,
#   Note(start=169.354762, end=169.881644, pitch=34, velocity=89)),
#  (35,
#   0,
#   False,
#   17000,
#   17010,
#   Note(start=169.999923, end=170.102074, pitch=34, velocity=76)),
#  (35,
#   0,
#   False,
#   17032,
#   17110,
#   Note(start=170.322504, end=171.096697, pitch=44, velocity=89)),
#  (35,
#   0,
#   False,
#   17129,
#   17139,
#   Note(start=171.290245, end=171.392396, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   17161,
#   17176,
#   Note(start=171.612826, end=171.763364, pitch=44, velocity=98)),
#  (35,
#   0,
#   False,
#   17194,
#   17238,
#   Note(start=171.935406, end=172.376267, pitch=44, velocity=105)),
#  (35,
#   0,
#   False,
#   17290,
#   17368,
#   Note(start=172.903148, end=173.677341, pitch=39, velocity=89)),
#  (35,
#   0,
#   False,
#   17387,
#   17397,
#   Note(start=173.870889, end=173.973040, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   17419,
#   17434,
#   Note(start=174.193470, end=174.344008, pitch=39, velocity=98)),
#  (35,
#   0,
#   False,
#   17452,
#   17496,
#   Note(start=174.516050, end=174.956911, pitch=39, velocity=105)),
#  (35,
#   0,
#   False,
#   17548,
#   17561,
#   Note(start=175.483792, end=175.612824, pitch=36, velocity=78)),
#  (35,
#   0,
#   False,
#   17581,
#   17638,
#   Note(start=175.806372, end=176.381641, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   17645,
#   17660,
#   Note(start=176.451533, end=176.596695, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   17677,
#   17699,
#   Note(start=176.774114, end=176.994544, pitch=36, velocity=85)),
#  (35,
#   0,
#   False,
#   17710,
#   17719,
#   Note(start=177.096694, end=177.193469, pitch=36, velocity=72)),
#  (35,
#   0,
#   False,
#   17742,
#   17751,
#   Note(start=177.419275, end=177.505296, pitch=36, velocity=72)),
#  (35,
#   0,
#   False,
#   17774,
#   17784,
#   Note(start=177.741855, end=177.844006, pitch=36, velocity=95)),
#  (35,
#   0,
#   False,
#   17806,
#   17818,
#   Note(start=178.064436, end=178.177339, pitch=44, velocity=61)),
#  (35,
#   0,
#   False,
#   17839,
#   17906,
#   Note(start=178.387016, end=179.064436, pitch=44, velocity=95)),
#  (35,
#   0,
#   False,
#   17903,
#   17932,
#   Note(start=179.032177, end=179.322500, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   17935,
#   17946,
#   Note(start=179.354758, end=179.462285, pitch=44, velocity=102)),
#  (35,
#   0,
#   False,
#   17968,
#   18023,
#   Note(start=179.677338, end=180.231102, pitch=44, velocity=100)),
#  (35,
#   0,
#   False,
#   18032,
#   18040,
#   Note(start=180.322499, end=180.397768, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   18065,
#   18140,
#   Note(start=180.645080, end=181.397768, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   18161,
#   18171,
#   Note(start=181.612821, end=181.714972, pitch=34, velocity=72)),
#  (35,
#   0,
#   False,
#   18194,
#   18206,
#   Note(start=181.935402, end=182.059058, pitch=34, velocity=82)),
#  (35,
#   0,
#   False,
#   18226,
#   18269,
#   Note(start=182.257982, end=182.693466, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   18290,
#   18313,
#   Note(start=182.903143, end=183.134326, pitch=34, velocity=98)),
#  (35,
#   0,
#   False,
#   18323,
#   18406,
#   Note(start=183.225724, end=184.059057, pitch=34, velocity=80)),
#  (35,
#   0,
#   False,
#   18419,
#   18432,
#   Note(start=184.193465, end=184.317121, pitch=34, velocity=63)),
#  (35,
#   0,
#   False,
#   18452,
#   18467,
#   Note(start=184.516046, end=184.666584, pitch=34, velocity=70)),
#  (35,
#   0,
#   False,
#   18484,
#   18512,
#   Note(start=184.838626, end=185.123573, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   18516,
#   18534,
#   Note(start=185.161207, end=185.344003, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   18548,
#   18560,
#   Note(start=185.483787, end=185.602067, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   18581,
#   18666,
#   Note(start=185.806368, end=186.661206, pitch=34, velocity=89)),
#  (35,
#   0,
#   False,
#   18677,
#   18689,
#   Note(start=186.774109, end=186.887013, pitch=34, velocity=76)),
#  (35,
#   0,
#   False,
#   18710,
#   18723,
#   Note(start=187.096690, end=187.225722, pitch=34, velocity=70)),
#  (35,
#   0,
#   False,
#   18742,
#   18797,
#   Note(start=187.419270, end=187.973034, pitch=34, velocity=100)),
#  (35,
#   0,
#   False,
#   18806,
#   18839,
#   Note(start=188.064431, end=188.387012, pitch=34, velocity=89)),
#  (35,
#   0,
#   False,
#   18839,
#   18851,
#   Note(start=188.387012, end=188.510668, pitch=39, velocity=80)),
#  (35,
#   0,
#   False,
#   18871,
#   18932,
#   Note(start=188.709592, end=189.322495, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   18935,
#   18945,
#   Note(start=189.354753, end=189.446151, pitch=38, velocity=78)),
#  (35,
#   0,
#   False,
#   18968,
#   18984,
#   Note(start=189.677334, end=189.838624, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   19000,
#   19032,
#   Note(start=189.999914, end=190.322495, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   19032,
#   19097,
#   Note(start=190.322495, end=190.967656, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   19097,
#   19110,
#   Note(start=190.967656, end=191.096688, pitch=44, velocity=74)),
#  (35,
#   0,
#   False,
#   19129,
#   19193,
#   Note(start=191.290236, end=191.930021, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   19194,
#   19213,
#   Note(start=191.935397, end=192.128946, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   19226,
#   19290,
#   Note(start=192.257978, end=192.903139, pitch=44, velocity=91)),
#  (35,
#   0,
#   False,
#   19290,
#   19355,
#   Note(start=192.903139, end=193.548300, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   19355,
#   19367,
#   Note(start=193.548300, end=193.666580, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   19387,
#   19450,
#   Note(start=193.870880, end=194.499912, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   19452,
#   19467,
#   Note(start=194.516041, end=194.666579, pitch=24, velocity=82)),
#  (35,
#   0,
#   False,
#   19484,
#   19548,
#   Note(start=194.838622, end=195.483783, pitch=36, velocity=91)),
#  (35,
#   0,
#   False,
#   19548,
#   19565,
#   Note(start=195.483783, end=195.645073, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   19581,
#   19613,
#   Note(start=195.806363, end=196.128944, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   19613,
#   19626,
#   Note(start=196.128944, end=196.257976, pitch=44, velocity=74)),
#  (35,
#   0,
#   False,
#   19645,
#   19709,
#   Note(start=196.451524, end=197.091309, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   19710,
#   19729,
#   Note(start=197.096685, end=197.290234, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   19742,
#   19806,
#   Note(start=197.419266, end=198.064427, pitch=44, velocity=91)),
#  (35,
#   0,
#   False,
#   19806,
#   19823,
#   Note(start=198.064427, end=198.225717, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   19839,
#   19871,
#   Note(start=198.387007, end=198.709588, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   19871,
#   19881,
#   Note(start=198.709588, end=198.811738, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   19903,
#   19960,
#   Note(start=199.032168, end=199.596684, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   19968,
#   19976,
#   Note(start=199.677329, end=199.763351, pitch=39, velocity=87)),
#  (35,
#   0,
#   False,
#   20000,
#   20065,
#   Note(start=199.999910, end=200.645071, pitch=39, velocity=91)),
#  (35,
#   0,
#   False,
#   20065,
#   20081,
#   Note(start=200.645071, end=200.806361, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   20097,
#   20129,
#   Note(start=200.967651, end=201.290232, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   20129,
#   20139,
#   Note(start=201.290232, end=201.392382, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   20161,
#   20218,
#   Note(start=201.612812, end=202.177328, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   20226,
#   20234,
#   Note(start=202.257973, end=202.343995, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   20258,
#   20274,
#   Note(start=202.580554, end=202.741844, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   20290,
#   20323,
#   Note(start=202.903134, end=203.225715, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   20323,
#   20339,
#   Note(start=203.225715, end=203.387005, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   20355,
#   20387,
#   Note(start=203.548295, end=203.870876, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   20387,
#   20399,
#   Note(start=203.870876, end=203.989156, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   20419,
#   20482,
#   Note(start=204.193456, end=204.822488, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   20484,
#   20499,
#   Note(start=204.838617, end=204.989155, pitch=24, velocity=82)),
#  (35,
#   0,
#   False,
#   20516,
#   20532,
#   Note(start=205.161198, end=205.322488, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   20548,
#   20581,
#   Note(start=205.483778, end=205.806359, pitch=36, velocity=85)),
#  (35,
#   0,
#   False,
#   20581,
#   20645,
#   Note(start=205.806359, end=206.451520, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   20645,
#   20658,
#   Note(start=206.451520, end=206.580552, pitch=44, velocity=74)),
#  (35,
#   0,
#   False,
#   20677,
#   20741,
#   Note(start=206.774100, end=207.413885, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   20742,
#   20761,
#   Note(start=207.419261, end=207.612810, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   20774,
#   20790,
#   Note(start=207.741842, end=207.903132, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   20806,
#   20839,
#   Note(start=208.064422, end=208.387003, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   20839,
#   20903,
#   Note(start=208.387003, end=209.032164, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   20903,
#   20916,
#   Note(start=209.032164, end=209.161196, pitch=39, velocity=74)),
#  (35,
#   0,
#   False,
#   20935,
#   20999,
#   Note(start=209.354744, end=209.994529, pitch=39, velocity=82)),
#  (35,
#   0,
#   False,
#   21000,
#   21019,
#   Note(start=209.999905, end=210.193454, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   21032,
#   21097,
#   Note(start=210.322486, end=210.967647, pitch=39, velocity=91)),
#  (35,
#   0,
#   False,
#   21097,
#   21161,
#   Note(start=210.967647, end=211.612808, pitch=34, velocity=91)),
#  (35,
#   0,
#   False,
#   21161,
#   21174,
#   Note(start=211.612808, end=211.741840, pitch=44, velocity=74)),
#  (35,
#   0,
#   False,
#   21194,
#   21258,
#   Note(start=211.935388, end=212.575173, pitch=44, velocity=82)),
#  (35,
#   0,
#   False,
#   21258,
#   21277,
#   Note(start=212.580549, end=212.774098, pitch=39, velocity=85)),
#  (35,
#   0,
#   False,
#   21290,
#   21306,
#   Note(start=212.903130, end=213.064420, pitch=44, velocity=87)),
#  (35,
#   0,
#   False,
#   21323,
#   21355,
#   Note(start=213.225710, end=213.548291, pitch=44, velocity=85)),
#  (35,
#   0,
#   False,
#   21355,
#   21371,
#   Note(start=213.548291, end=213.709581, pitch=34, velocity=87)),
#  (35,
#   0,
#   False,
#   21387,
#   21419,
#   Note(start=213.870871, end=214.193452, pitch=34, velocity=85)),
#  (35,
#   0,
#   False,
#   21419,
#   21431,
#   Note(start=214.193452, end=214.311732, pitch=36, velocity=82)),
#  (35,
#   0,
#   False,
#   21452,
#   21515,
#   Note(start=214.516032, end=215.145064, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   21516,
#   21531,
#   Note(start=215.161193, end=215.311731, pitch=24, velocity=82)),
#  (35,
#   0,
#   False,
#   21548,
#   21565,
#   Note(start=215.483774, end=215.645064, pitch=36, velocity=87)),
#  (35,
#   0,
#   False,
#   21581,
#   21613,
#   Note(start=215.806354, end=216.128935, pitch=36, velocity=85)),
#  (35,
#   0,
#   False,
#   21613,
#   21677,
# ...
#  (25,
#   1,
#   False,
#   8774,
#   8911,
#   Note(start=87.741896, end=89.107487, pitch=60, velocity=63)),
#  (25,
#   1,
#   False,
#   8774,
#   8912,
#   Note(start=87.741896, end=89.118239, pitch=63, velocity=72)),
#  (25,
#   1,
#   False,
#   8935,
#   8945,
#   Note(start=89.354798, end=89.451573, pitch=60, velocity=58)),
#  (25,
#   1,
#   False,
#   8935,
#   8946,
#   Note(start=89.354798, end=89.456949, pitch=63, velocity=72)),
#  (25,
#   1,
#   False,
#   8774,
#   8950,
#   Note(start=87.741896, end=89.499960, pitch=67, velocity=72)),
#  (25,
#   1,
#   False,
#   8968,
#   8977,
#   Note(start=89.677379, end=89.774153, pitch=60, velocity=82)),
#  (25,
#   1,
#   False,
#   8968,
#   8978,
#   Note(start=89.677379, end=89.784906, pitch=63, velocity=80)),
#  (25,
#   1,
#   False,
#   8968,
#   8988,
#   Note(start=89.677379, end=89.876304, pitch=67, velocity=62)),
#  (25,
#   1,
#   False,
#   9000,
#   9009,
#   Note(start=89.999959, end=90.091357, pitch=60, velocity=68)),
#  (25,
#   1,
#   False,
#   9000,
#   9011,
#   Note(start=89.999959, end=90.107486, pitch=63, velocity=70)),
#  (25,
#   1,
#   False,
#   9000,
#   9012,
#   Note(start=89.999959, end=90.118239, pitch=67, velocity=61)),
#  (25,
#   1,
#   False,
#   8774,
#   9015,
#   Note(start=87.741896, end=90.150497, pitch=48, velocity=68)),
#  (25,
#   1,
#   False,
#   9032,
#   9158,
#   Note(start=90.322540, end=91.580604, pitch=60, velocity=63)),
#  (25,
#   1,
#   False,
#   9032,
#   9169,
#   Note(start=90.322540, end=91.688131, pitch=63, velocity=63)),
#  (25,
#   1,
#   False,
#   9032,
#   9170,
#   Note(start=90.322540, end=91.698883, pitch=68, velocity=72)),
#  (25,
#   1,
#   False,
#   9194,
#   9203,
#   Note(start=91.935442, end=92.032217, pitch=63, velocity=58)),
#  (25,
#   1,
#   False,
#   9194,
#   9204,
#   Note(start=91.935442, end=92.037593, pitch=68, velocity=72)),
#  (25,
#   1,
#   False,
#   9032,
#   9208,
#   Note(start=90.322540, end=92.080604, pitch=72, velocity=72)),
#  (25,
#   1,
#   False,
#   9226,
#   9235,
#   Note(start=92.258023, end=92.354797, pitch=63, velocity=82)),
#  (25,
#   1,
#   False,
#   9226,
#   9237,
#   Note(start=92.258023, end=92.365550, pitch=68, velocity=80)),
#  (25,
#   1,
#   False,
#   9226,
#   9246,
#   Note(start=92.258023, end=92.456948, pitch=72, velocity=62)),
#  (25,
#   1,
#   False,
#   9258,
#   9267,
#   Note(start=92.580603, end=92.672001, pitch=63, velocity=68)),
#  (25,
#   1,
#   False,
#   9258,
#   9269,
#   Note(start=92.580603, end=92.688130, pitch=68, velocity=70)),
#  (25,
#   1,
#   False,
#   9258,
#   9270,
#   Note(start=92.580603, end=92.698883, pitch=72, velocity=61)),
#  (25,
#   1,
#   False,
#   9032,
#   9273,
#   Note(start=90.322540, end=92.731141, pitch=44, velocity=68)),
#  (25,
#   1,
#   False,
#   9387,
#   9410,
#   Note(start=93.870925, end=94.102108, pitch=73, velocity=40)),
#  (25,
#   1,
#   False,
#   9355,
#   9410,
#   Note(start=93.548345, end=94.102108, pitch=68, velocity=38)),
#  (25,
#   1,
#   False,
#   9323,
#   9415,
#   Note(start=93.225764, end=94.150495, pitch=63, velocity=57)),
#  (25,
#   1,
#   False,
#   9290,
#   9419,
#   Note(start=92.903184, end=94.188130, pitch=61, velocity=64)),
#  (25,
#   1,
#   False,
#   9419,
#   9542,
#   Note(start=94.193506, end=95.419312, pitch=60, velocity=57)),
#  (25,
#   1,
#   False,
#   9419,
#   9546,
#   Note(start=94.193506, end=95.456946, pitch=72, velocity=72)),
#  (25,
#   1,
#   False,
#   9419,
#   9546,
#   Note(start=94.193506, end=95.456946, pitch=63, velocity=60)),
#  (25,
#   1,
#   False,
#   9419,
#   9548,
#   Note(start=94.193506, end=95.483828, pitch=44, velocity=45)),
#  (25,
#   1,
#   False,
#   9613,
#   9947,
#   Note(start=96.128989, end=99.473074, pitch=58, velocity=76)),
#  (25,
#   1,
#   False,
#   9903,
#   10015,
#   Note(start=99.032213, end=100.145116, pitch=67, velocity=70)),
#  (25,
#   1,
#   False,
#   9645,
#   10034,
#   Note(start=96.451569, end=100.338665, pitch=63, velocity=70)),
#  (25,
#   1,
#   False,
#   9968,
#   10034,
#   Note(start=99.677374, end=100.344041, pitch=58, velocity=55)),
#  (25,
#   1,
#   False,
#   9839,
#   10040,
#   Note(start=98.387052, end=100.397804, pitch=55, velocity=66)),
#  (25,
#   1,
#   False,
#   9581,
#   10048,
#   Note(start=95.806408, end=100.483826, pitch=39, velocity=57)),
#  (25,
#   1,
#   False,
#   10097,
#   10176,
#   Note(start=100.967696, end=101.758019, pitch=60, velocity=57)),
#  (25,
#   1,
#   False,
#   10129,
#   10177,
#   Note(start=101.290277, end=101.768771, pitch=68, velocity=85)),
#  (25,
#   1,
#   False,
#   10194,
#   10215,
#   Note(start=101.935438, end=102.150492, pitch=65, velocity=68)),
#  (25,
#   1,
#   False,
#   10194,
#   10215,
#   Note(start=101.935438, end=102.150492, pitch=61, velocity=68)),
#  (25,
#   1,
#   False,
#   10194,
#   10215,
#   Note(start=101.935438, end=102.150492, pitch=56, velocity=68)),
#  (25,
#   1,
#   False,
#   10226,
#   10308,
#   Note(start=102.258018, end=103.075222, pitch=56, velocity=82)),
#  (25,
#   1,
#   False,
#   10226,
#   10308,
#   Note(start=102.258018, end=103.075222, pitch=60, velocity=82)),
#  (25,
#   1,
#   False,
#   10226,
#   10308,
#   Note(start=102.258018, end=103.075222, pitch=63, velocity=82)),
#  (25,
#   1,
#   False,
#   10355,
#   10372,
#   Note(start=103.548340, end=103.715007, pitch=56, velocity=76)),
#  (25,
#   1,
#   False,
#   10355,
#   10372,
#   Note(start=103.548340, end=103.715007, pitch=61, velocity=76)),
#  (25,
#   1,
#   False,
#   10355,
#   10372,
#   Note(start=103.548340, end=103.715007, pitch=63, velocity=76)),
#  (25,
#   1,
#   False,
#   10548,
#   10572,
#   Note(start=105.483823, end=105.715006, pitch=72, velocity=40)),
#  (25,
#   1,
#   False,
#   10516,
#   10572,
#   Note(start=105.161243, end=105.715006, pitch=68, velocity=38)),
#  (25,
#   1,
#   False,
#   10484,
#   10576,
#   Note(start=104.838662, end=105.763393, pitch=63, velocity=57)),
#  (25,
#   1,
#   False,
#   10452,
#   10580,
#   Note(start=104.516082, end=105.801028, pitch=60, velocity=64)),
#  (25,
#   1,
#   False,
#   10581,
#   10727,
#   Note(start=105.806404, end=107.274145, pitch=55, velocity=68)),
#  (25,
#   1,
#   False,
#   10581,
#   10735,
#   Note(start=105.806404, end=107.354790, pitch=58, velocity=66)),
#  (25,
#   1,
#   False,
#   10581,
#   10747,
#   Note(start=105.806404, end=107.473070, pitch=63, velocity=80)),
#  (25,
#   1,
#   False,
#   10742,
#   10778,
#   Note(start=107.419306, end=107.784898, pitch=55, velocity=80)),
#  (25,
#   1,
#   False,
#   10774,
#   10792,
#   Note(start=107.741887, end=107.924683, pitch=58, velocity=98)),
#  (25,
#   1,
#   False,
#   10581,
#   10804,
#   Note(start=105.806404, end=108.042962, pitch=67, velocity=76)),
#  (25,
#   1,
#   False,
#   10871,
#   11006,
#   Note(start=108.709628, end=110.059090, pitch=60, velocity=49)),
#  (25,
#   1,
#   False,
#   10871,
#   11015,
#   Note(start=108.709628, end=110.145112, pitch=63, velocity=57)),
#  (25,
#   1,
#   False,
#   10871,
#   11029,
#   Note(start=108.709628, end=110.290273, pitch=67, velocity=68)),
#  (25,
#   1,
#   False,
#   11065,
#   11081,
#   Note(start=110.645111, end=110.811778, pitch=67, velocity=100)),
#  (25,
#   1,
#   False,
#   11016,
#   11089,
#   Note(start=110.161241, end=110.887047, pitch=60, velocity=74)),
#  (25,
#   1,
#   False,
#   11048,
#   11089,
#   Note(start=110.483821, end=110.887047, pitch=63, velocity=74)),
#  (25,
#   1,
#   False,
#   11000,
#   11091,
#   Note(start=109.999950, end=110.908552, pitch=55, velocity=80)),
#  (25,
#   1,
#   False,
#   10871,
#   11097,
#   Note(start=108.709628, end=110.967692, pitch=48, velocity=62)),
#  (25,
#   1,
#   False,
#   11097,
#   11244,
#   Note(start=110.967692, end=112.435433, pitch=58, velocity=68)),
#  (25,
#   1,
#   False,
#   11097,
#   11252,
#   Note(start=110.967692, end=112.516078, pitch=62, velocity=66)),
#  (25,
#   1,
#   False,
#   11097,
#   11263,
#   Note(start=110.967692, end=112.634358, pitch=67, velocity=80)),
#  (25,
#   1,
#   False,
#   11258,
#   11295,
#   Note(start=112.580594, end=112.946186, pitch=58, velocity=80)),
#  (25,
#   1,
#   False,
#   11290,
#   11309,
#   Note(start=112.903175, end=113.085971, pitch=62, velocity=98)),
#  (25,
#   1,
#   False,
#   11097,
#   11320,
#   Note(start=110.967692, end=113.204250, pitch=70, velocity=76)),
#  (25,
#   1,
#   False,
#   11387,
#   11522,
#   Note(start=113.870916, end=115.220378, pitch=63, velocity=49)),
#  (25,
#   1,
#   False,
#   11387,
#   11531,
#   Note(start=113.870916, end=115.306400, pitch=68, velocity=57)),
#  (25,
#   1,
#   False,
#   11387,
#   11545,
#   Note(start=113.870916, end=115.451561, pitch=72, velocity=68)),
#  (25,
#   1,
#   False,
#   11581,
#   11597,
#   Note(start=115.806399, end=115.973066, pitch=72, velocity=100)),
#  (25,
#   1,
#   False,
#   11532,
#   11605,
#   Note(start=115.322529, end=116.048335, pitch=63, velocity=74)),
#  (25,
#   1,
#   False,
#   11565,
#   11605,
#   Note(start=115.645109, end=116.048335, pitch=68, velocity=74)),
#  (25,
#   1,
#   False,
#   11516,
#   11607,
#   Note(start=115.161238, end=116.069840, pitch=60, velocity=80)),
#  (25,
#   1,
#   False,
#   11387,
#   11613,
#   Note(start=113.870916, end=116.128980, pitch=44, velocity=62)),
#  (25,
#   1,
#   False,
#   11613,
#   11672,
#   Note(start=116.128980, end=116.715001, pitch=53, velocity=70)),
#  (25,
#   1,
#   False,
#   11710,
#   11738,
#   Note(start=117.096721, end=117.376291, pitch=58, velocity=70)),
#  (25,
#   1,
#   False,
#   11613,
#   11741,
#   Note(start=116.128980, end=117.408549, pitch=65, velocity=63)),
#  (25,
#   1,
#   False,
#   11677,
#   11742,
#   Note(start=116.774141, end=117.419302, pitch=53, velocity=68)),
#  (25,
#   1,
#   False,
#   11613,
#   11742,
#   Note(start=116.128980, end=117.419302, pitch=62, velocity=74)),
#  (25,
#   1,
#   False,
#   11742,
#   11865,
#   Note(start=117.419302, end=118.645108, pitch=55, velocity=57)),
#  (25,
#   1,
#   False,
#   11742,
#   11868,
#   Note(start=117.419302, end=118.682742, pitch=67, velocity=72)),
#  (25,
#   1,
#   False,
#   11742,
#   11868,
#   Note(start=117.419302, end=118.682742, pitch=60, velocity=60)),
#  (25,
#   1,
#   False,
#   11742,
#   11871,
#   Note(start=117.419302, end=118.709624, pitch=48, velocity=45)),
#  (25,
#   1,
#   False,
#   11903,
#   12038,
#   Note(start=119.032204, end=120.381666, pitch=63, velocity=49)),
#  (25,
#   1,
#   False,
#   11903,
#   12047,
#   Note(start=119.032204, end=120.467688, pitch=68, velocity=57)),
#  (25,
#   1,
#   False,
#   11903,
#   12061,
#   Note(start=119.032204, end=120.612849, pitch=72, velocity=68)),
#  (25,
#   1,
#   False,
#   12097,
#   12113,
#   Note(start=120.967687, end=121.134354, pitch=72, velocity=100)),
#  (25,
#   1,
#   False,
#   12048,
#   12121,
#   Note(start=120.483817, end=121.209623, pitch=63, velocity=74)),
#  (25,
#   1,
#   False,
#   12081,
#   12121,
#   Note(start=120.806397, end=121.209623, pitch=68, velocity=74)),
#  (25,
#   1,
#   False,
#   12032,
#   12123,
#   Note(start=120.322526, end=121.231128, pitch=60, velocity=80)),
#  (25,
#   1,
#   False,
#   11903,
#   12129,
#   Note(start=119.032204, end=121.290268, pitch=44, velocity=62)),
#  (25,
#   1,
#   False,
#   12161,
#   12178,
#   Note(start=121.612848, end=121.779515, pitch=58, velocity=76)),
#  (25,
#   1,
#   False,
#   12161,
#   12178,
#   Note(start=121.612848, end=121.779515, pitch=62, velocity=76)),
#  (25,
#   1,
#   False,
#   12161,
#   12178,
#   Note(start=121.612848, end=121.779515, pitch=65, velocity=76)),
#  (25,
#   1,
#   False,
#   12290,
#   12307,
#   Note(start=122.903170, end=123.069837, pitch=55, velocity=76)),
#  (25,
#   1,
#   False,
#   12290,
#   12307,
#   Note(start=122.903170, end=123.069837, pitch=60, velocity=76)),
#  (25,
#   1,
#   False,
#   12290,
#   12307,
#   Note(start=122.903170, end=123.069837, pitch=63, velocity=76)),
#  (25,
#   1,
#   False,
#   12484,
#   12588,
#   Note(start=124.838653, end=125.876287, pitch=68, velocity=89)),
#  (25,
#   1,
#   False,
#   12452,
#   12588,
#   Note(start=124.516073, end=125.876287, pitch=63, velocity=80)),
#  (25,
#   1,
#   False,
#   12419,
#   12588,
#   Note(start=124.193492, end=125.876287, pitch=60, velocity=70)),
#  (25,
#   1,
#   False,
#   12742,
#   12765,
#   Note(start=127.419297, end=127.650480, pitch=65, velocity=40)),
#  (25,
#   1,
#   False,
#   12710,
#   12765,
#   Note(start=127.096717, end=127.650480, pitch=62, velocity=38)),
#  (25,
#   1,
#   False,
#   12677,
#   12770,
#   Note(start=126.774136, end=127.698867, pitch=58, velocity=57)),
#  (25,
#   1,
#   False,
#   12645,
#   12774,
#   Note(start=126.451556, end=127.736502, pitch=53, velocity=64)),
#  (25,
#   1,
#   False,
#   12871,
#   12894,
#   Note(start=128.709619, end=128.940802, pitch=67, velocity=40)),
#  (25,
#   1,
#   False,
#   12839,
#   12894,
#   Note(start=128.387039, end=128.940802, pitch=63, velocity=38)),
#  (25,
#   1,
#   False,
#   12806,
#   12899,
#   Note(start=128.064458, end=128.989189, pitch=60, velocity=57)),
#  (25,
#   1,
#   False,
#   12774,
#   12903,
#   Note(start=127.741878, end=129.026824, pitch=55, velocity=64)),
#  (25,
#   1,
#   False,
#   12935,
#   13070,
#   Note(start=129.354780, end=130.704242, pitch=63, velocity=49)),
#  (25,
#   1,
#   False,
#   12935,
#   13079,
#   Note(start=129.354780, end=130.790264, pitch=68, velocity=57)),
#  (25,
#   1,
#   False,
#   12935,
#   13094,
#   Note(start=129.354780, end=130.935425, pitch=72, velocity=68)),
#  (25,
#   1,
#   False,
#   13129,
#   13146,
#   Note(start=131.290263, end=131.456930, pitch=72, velocity=100)),
#  (25,
#   1,
#   False,
#   13081,
#   13153,
#   Note(start=130.806393, end=131.532199, pitch=63, velocity=74)),
#  (25,
#   1,
#   False,
#   13113,
#   13153,
#   Note(start=131.128973, end=131.532199, pitch=68, velocity=74)),
#  (25,
#   1,
#   False,
#   13065,
#   13155,
#   Note(start=130.645102, end=131.553704, pitch=60, velocity=80)),
#  (25,
#   1,
#   False,
#   12935,
#   13161,
#   Note(start=129.354780, end=131.612844, pitch=44, velocity=62)),
#  (25,
#   1,
#   False,
#   13226,
#   13560,
#   Note(start=132.258005, end=135.602090, pitch=58, velocity=76)),
#  (25,
#   1,
#   False,
#   13516,
#   13627,
#   Note(start=135.161229, end=136.274132, pitch=65, velocity=70)),
#  (25,
#   1,
#   False,
#   13258,
#   13647,
#   Note(start=132.580585, end=136.467681, pitch=62, velocity=70)),
#  (25,
#   1,
#   False,
#   13581,
#   13647,
#   Note(start=135.806390, end=136.473057, pitch=58, velocity=55)),
#  (25,
#   1,
#   False,
#   13452,
#   13653,
#   Note(start=134.516068, end=136.526820, pitch=53, velocity=66)),
#  (25,
#   1,
#   False,
#   13194,
#   13661,
#   Note(start=131.935424, end=136.612842, pitch=46, velocity=57)),
#  (25,
#   1,
#   False,
#   13774,
#   13797,
#   Note(start=137.741873, end=137.973056, pitch=67, velocity=40)),
#  (25,
#   1,
#   False,
#   13742,
#   13797,
#   Note(start=137.419293, end=137.973056, pitch=63, velocity=38)),
#  (25,
#   1,
#   False,
#   13710,
#   13802,
#   Note(start=137.096712, end=138.021443, pitch=58, velocity=57)),
#  (25,
#   1,
#   False,
#   13677,
#   13806,
#   Note(start=136.774132, end=138.059078, pitch=55, velocity=64)),
#  (25,
#   1,
#   False,
#   13806,
#   13871,
#   Note(start=138.064454, end=138.709615, pitch=39, velocity=45)),
#  (25,
#   1,
#   False,
#   13806,
#   13871,
#   Note(start=138.064454, end=138.709615, pitch=67, velocity=72)),
#  (25,
#   1,
#   False,
#   13806,
#   13871,
#   Note(start=138.064454, end=138.709615, pitch=58, velocity=60)),
#  (25,
#   1,
#   False,
#   13806,
#   13871,
#   Note(start=138.064454, end=138.709615, pitch=55, velocity=57)),
#  (25,
#   1,
#   False,
#   13871,
#   13935,
#   Note(start=138.709615, end=139.354776, pitch=46, velocity=45)),
#  (25,
#   1,
#   False,
#   13871,
#   13935,
#   Note(start=138.709615, end=139.354776, pitch=65, velocity=72)),
#  (25,
#   1,
#   False,
#   13871,
#   13935,
#   Note(start=138.709615, end=139.354776, pitch=58, velocity=60)),
#  (25,
#   1,
#   False,
#   13871,
#   13935,
#   Note(start=138.709615, end=139.354776, pitch=53, velocity=57)),
#  (25,
#   1,
#   False,
#   13935,
#   13994,
#   Note(start=139.354776, end=139.940797, pitch=60, velocity=70)),
#  (25,
#   1,
#   False,
#   14032,
#   14060,
#   Note(start=140.322517, end=140.602087, pitch=63, velocity=70)),
#  (25,
#   1,
#   False,
#   13935,
#   14063,
#   Note(start=139.354776, end=140.634345, pitch=72, velocity=63)),
#  (25,
#   1,
#   False,
#   14000,
#   14065,
#   Note(start=139.999937, end=140.645098, pitch=60, velocity=68)),
#  (25,
#   1,
#   False,
#   13935,
#   14065,
#   Note(start=139.354776, end=140.645098, pitch=68, velocity=74)),
#  (25,
#   1,
#   False,
#   14065,
#   14129,
#   Note(start=140.645098, end=141.290259, pitch=44, velocity=45)),
#  (25,
#   1,
#   False,
#   14065,
#   14129,
#   Note(start=140.645098, end=141.290259, pitch=72, velocity=72)),
#  (25,
#   1,
#   False,
#   14065,
#   14129,
#   Note(start=140.645098, end=141.290259, pitch=63, velocity=60)),
#  (25,
#   1,
#   False,
#   14065,
#   14129,
#   Note(start=140.645098, end=141.290259, pitch=60, velocity=57)),
#  (25,
#   1,
#   False,
#   14161,
#   14178,
#   Note(start=141.612839, end=141.779506, pitch=58, velocity=76)),
#  (25,
#   1,
#   False,
#   14161,
#   14178,
#   Note(start=141.612839, end=141.779506, pitch=62, velocity=76)),
#  (25,
#   1,
#   False,
#   14161,
#   14178,
#   Note(start=141.612839, end=141.779506, pitch=65, velocity=76)),
#  (25,
#   1,
#   False,
#   14194,
#   14316,
#   Note(start=141.935420, end=143.161226, pitch=55, velocity=57)),
#  ...]
