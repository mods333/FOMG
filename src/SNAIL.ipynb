# %%
import math

from loaders import *
from episode import *
from dataset import *

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
class CausalConv1d(nn.Module):
    # https://discuss.pytorch.org/t/causal-convolution/3456/4
    def __init__(self, in_channels, out_channels, kernel = 2,dilation=2):
        super(CausalConv1d, self).__init__()
        
        self.kernel = kernel
        self.padding = (kernel - 1)*dilation
        self.dilation = dilation
        self.causal_conv = nn.Conv1d(in_channels, out_channels, 2, padding = self.padding, dilation = dilation)

    def forward(self, input):
        return self.causal_conv(input)[:, :, :-self.padding]

# %%
class DenseBlock(nn.Module):
    
    def __init__(self,in_channels,num_filters,dilation_rate = 2):
        
        super(DenseBlock,self).__init__()
        
        self.causal_conv = CausalConv1d(in_channels,num_filters,dilation=dilation_rate)
        
    def forward(self,input):
        
        xf = F.tanh(self.causal_conv(input))
        xb = F.sigmoid(self.causal_conv(input))
        
        activations = xf*gf
        
        return torch.cat([input,activations],dim = 1)

# %%
class TCBlock(nn.Module):
    
    
    def __init__(self, in_channels, filters, seq_len):
        
        super(TCBlock, self).__init__()
        layer_count = math.ceil(math.log(seq_len)/math.log(2))
        blocks = []
        channel_count = in_channels
        for layer in range(layer_count):
            block = DenseBlock(channel_count, filters, dilation=2**layer)
            blocks.append(block)
            channel_count += filters
        self.blocks = nn.Sequential(*blocks)

    def forward(self, input):
        return self.blocks(input)

# %%
class AttetionBlock(nn.Module):
    
    def __init__(self, dims, k_size, v_size, seq_len):
        
        super(AttentionBlock, self).__init__()
        
        self.key_layer = nn.Linear(dims, k_size)
        self.query_layer = nn.Linear(dims, k_size)
        self.value_layer = nn.Linear(dims, v_size)
        self.sqrt_k = math.sqrt(k_size)
        
    def forward(self,input):
        
        keys = self.key_layer(input)
        queries = self.query_layer(input)
        
        logits = torch.bmm(queries, keys.transpose(2,1))
        
        mask = np.triu(np.ones(logits.size()), k=1).astype('uint8')
        mask = torch.from_numpy(mask)
        # do masked_fill_ on data rather than Variable because PyTorch doesn't
        # support masked_fill_ w/-inf directly on Variables for some reason.
        logits.data.masked_fill_(mask, float('-inf'))
        probs = F.softmax(logits, dim=1) / self.sqrt_k
        read = torch.bmm(probs, values)
        return torch.cat([minibatch, read], dim=2)

# %%
""" Some global variables """
_loader = Loader(502) # 500 + SOS + EOS
loader = MIDILoader(_loader)

use_cuda = torch.cuda.is_available()
# Is the tokenizer 1 indexed?
vocabulary_size = 16*128*2 + 32*16 + 100 + 1 # 4708 + 1
vocabulary_size = vocabulary_size + 2 # SOS (index 4709) and EOS (index 4710)
SOS_TOKEN = 4709
EOS_TOKEN = 4710

encoding_size = 500
one_hot_embeddings = np.eye(vocabulary_size)

# %%
eps = load_sampler_from_config("../src/test.yaml")
# Out:
# INFO:few-shot:Preprocessing data. 0.00%
# INFO:few-shot:Preprocessing data. 3.12%
# INFO:few-shot:Preprocessing data. 9.93%
# INFO:few-shot:Preprocessing data. 10.11%
# /home/suhail/anaconda3/lib/python3.6/site-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# /home/suhail/anaconda3/lib/python3.6/site-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# INFO:few-shot:Preprocessing data. 10.29%
# INFO:few-shot:Preprocessing data. 10.48%
# INFO:few-shot:Preprocessing data. 10.66%
# /home/suhail/anaconda3/lib/python3.6/site-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# INFO:few-shot:Preprocessing data. 11.03%
# /home/suhail/anaconda3/lib/python3.6/site-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# INFO:few-shot:Preprocessing data. 11.21%
# INFO:few-shot:Preprocessing data. 11.58%
# INFO:few-shot:Preprocessing data. 11.95%
# INFO:few-shot:Preprocessing data. 12.32%
# INFO:few-shot:Preprocessing data. 12.50%
# INFO:few-shot:Preprocessing data. 12.68%
# INFO:few-shot:Preprocessing data. 12.87%
# INFO:few-shot:Preprocessing data. 13.05%
# INFO:few-shot:Preprocessing data. 13.42%
# INFO:few-shot:Preprocessing data. 13.60%
# INFO:few-shot:Preprocessing data. 13.79%
# INFO:few-shot:Preprocessing data. 13.97%
# INFO:few-shot:Preprocessing data. 14.15%
# INFO:few-shot:Preprocessing data. 14.52%
# INFO:few-shot:Preprocessing data. 14.71%
# INFO:few-shot:Preprocessing data. 14.89%
# INFO:few-shot:Preprocessing data. 15.07%
# INFO:few-shot:Preprocessing data. 15.26%
# INFO:few-shot:Preprocessing data. 15.62%
# INFO:few-shot:Preprocessing data. 15.81%
# INFO:few-shot:Preprocessing data. 15.99%
# INFO:few-shot:Preprocessing data. 16.18%
# INFO:few-shot:Preprocessing data. 16.36%
# INFO:few-shot:Preprocessing data. 16.54%
# INFO:few-shot:Preprocessing data. 16.73%
# INFO:few-shot:Preprocessing data. 16.91%
# INFO:few-shot:Preprocessing data. 17.28%
# INFO:few-shot:Preprocessing data. 17.46%
# INFO:few-shot:Preprocessing data. 17.65%
# INFO:few-shot:Preprocessing data. 17.83%
# INFO:few-shot:Preprocessing data. 18.01%
# INFO:few-shot:Preprocessing data. 18.20%
# INFO:few-shot:Preprocessing data. 18.57%
# INFO:few-shot:Preprocessing data. 18.75%
# INFO:few-shot:Preprocessing data. 18.93%
# INFO:few-shot:Preprocessing data. 19.12%
# INFO:few-shot:Preprocessing data. 19.30%
# INFO:few-shot:Preprocessing data. 19.49%
# INFO:few-shot:Preprocessing data. 19.67%
# INFO:few-shot:Preprocessing data. 19.85%
# INFO:few-shot:Preprocessing data. 20.04%
# INFO:few-shot:Preprocessing data. 20.22%
# INFO:few-shot:Preprocessing data. 20.59%
# INFO:few-shot:Preprocessing data. 20.77%
# INFO:few-shot:Preprocessing data. 20.96%
# INFO:few-shot:Preprocessing data. 21.14%
# INFO:few-shot:Preprocessing data. 21.32%
# INFO:few-shot:Preprocessing data. 21.51%
# INFO:few-shot:Preprocessing data. 21.69%
# INFO:few-shot:Preprocessing data. 21.88%
# INFO:few-shot:Preprocessing data. 22.06%
# INFO:few-shot:Preprocessing data. 22.24%
# INFO:few-shot:Preprocessing data. 22.43%
# INFO:few-shot:Preprocessing data. 22.61%
# INFO:few-shot:Preprocessing data. 22.98%
# INFO:few-shot:Preprocessing data. 23.16%
# INFO:few-shot:Preprocessing data. 23.35%
# INFO:few-shot:Preprocessing data. 23.53%
# INFO:few-shot:Preprocessing data. 23.71%
# INFO:few-shot:Preprocessing data. 23.90%
# INFO:few-shot:Preprocessing data. 24.08%
# INFO:few-shot:Preprocessing data. 24.26%
# INFO:few-shot:Preprocessing data. 24.45%
# INFO:few-shot:Preprocessing data. 24.63%
# INFO:few-shot:Preprocessing data. 24.82%
# INFO:few-shot:Preprocessing data. 25.18%
# INFO:few-shot:Preprocessing data. 25.37%
# INFO:few-shot:Preprocessing data. 25.74%
# INFO:few-shot:Preprocessing data. 25.92%
# INFO:few-shot:Preprocessing data. 26.10%
# INFO:few-shot:Preprocessing data. 26.29%
# INFO:few-shot:Preprocessing data. 26.47%
# INFO:few-shot:Preprocessing data. 26.84%
# INFO:few-shot:Preprocessing data. 27.02%
# INFO:few-shot:Preprocessing data. 27.39%
# INFO:few-shot:Preprocessing data. 27.57%
# INFO:few-shot:Preprocessing data. 27.76%
# INFO:few-shot:Preprocessing data. 27.94%
# INFO:few-shot:Preprocessing data. 28.12%
# INFO:few-shot:Preprocessing data. 28.31%
# INFO:few-shot:Preprocessing data. 28.49%
# INFO:few-shot:Preprocessing data. 28.68%
# INFO:few-shot:Preprocessing data. 28.86%
# INFO:few-shot:Preprocessing data. 29.23%
# INFO:few-shot:Preprocessing data. 29.41%
# INFO:few-shot:Preprocessing data. 29.60%
# INFO:few-shot:Preprocessing data. 29.78%
# INFO:few-shot:Preprocessing data. 29.96%
# INFO:few-shot:Preprocessing data. 30.15%
# INFO:few-shot:Preprocessing data. 30.33%
# INFO:few-shot:Preprocessing data. 30.51%
# INFO:few-shot:Preprocessing data. 30.70%
# INFO:few-shot:Preprocessing data. 30.88%
# INFO:few-shot:Preprocessing data. 31.07%
# INFO:few-shot:Preprocessing data. 31.43%
# INFO:few-shot:Preprocessing data. 31.62%
# INFO:few-shot:Preprocessing data. 31.80%
# INFO:few-shot:Preprocessing data. 31.99%
# INFO:few-shot:Preprocessing data. 32.17%
# INFO:few-shot:Preprocessing data. 32.35%
# INFO:few-shot:Preprocessing data. 32.54%
# INFO:few-shot:Preprocessing data. 32.90%
# INFO:few-shot:Preprocessing data. 33.09%
# INFO:few-shot:Preprocessing data. 33.27%
# INFO:few-shot:Preprocessing data. 33.46%
# INFO:few-shot:Preprocessing data. 33.82%
# INFO:few-shot:Preprocessing data. 34.01%
# INFO:few-shot:Preprocessing data. 34.19%
# INFO:few-shot:Preprocessing data. 34.38%
# INFO:few-shot:Preprocessing data. 34.56%
# INFO:few-shot:Preprocessing data. 34.74%
# INFO:few-shot:Preprocessing data. 34.93%
# INFO:few-shot:Preprocessing data. 35.11%
# INFO:few-shot:Preprocessing data. 35.29%
# INFO:few-shot:Preprocessing data. 35.48%
# INFO:few-shot:Preprocessing data. 35.66%
# INFO:few-shot:Preprocessing data. 35.85%
# INFO:few-shot:Preprocessing data. 36.03%
# INFO:few-shot:Preprocessing data. 36.40%
# INFO:few-shot:Preprocessing data. 36.58%
# INFO:few-shot:Preprocessing data. 36.76%
# INFO:few-shot:Preprocessing data. 36.95%
# INFO:few-shot:Preprocessing data. 37.32%
# INFO:few-shot:Preprocessing data. 37.50%
# INFO:few-shot:Preprocessing data. 37.68%
# INFO:few-shot:Preprocessing data. 38.05%
# INFO:few-shot:Preprocessing data. 38.24%
# INFO:few-shot:Preprocessing data. 38.42%
# INFO:few-shot:Preprocessing data. 38.60%
# INFO:few-shot:Preprocessing data. 38.79%
# INFO:few-shot:Preprocessing data. 38.97%
# INFO:few-shot:Preprocessing data. 39.34%
# INFO:few-shot:Preprocessing data. 39.71%
# INFO:few-shot:Preprocessing data. 39.89%
# INFO:few-shot:Preprocessing data. 40.07%
# INFO:few-shot:Preprocessing data. 40.44%
# INFO:few-shot:Preprocessing data. 40.62%
# INFO:few-shot:Preprocessing data. 40.81%
# INFO:few-shot:Preprocessing data. 40.99%
# INFO:few-shot:Preprocessing data. 41.18%
# INFO:few-shot:Preprocessing data. 41.36%
# INFO:few-shot:Preprocessing data. 41.54%
# INFO:few-shot:Preprocessing data. 41.73%
# INFO:few-shot:Preprocessing data. 41.91%
# INFO:few-shot:Preprocessing data. 42.10%
# INFO:few-shot:Preprocessing data. 42.28%
# INFO:few-shot:Preprocessing data. 42.46%
# INFO:few-shot:Preprocessing data. 42.65%
# INFO:few-shot:Preprocessing data. 42.83%
# INFO:few-shot:Preprocessing data. 43.01%
# INFO:few-shot:Preprocessing data. 43.38%
# INFO:few-shot:Preprocessing data. 43.57%
# INFO:few-shot:Preprocessing data. 43.93%
# INFO:few-shot:Preprocessing data. 44.12%
# INFO:few-shot:Preprocessing data. 44.30%
# INFO:few-shot:Preprocessing data. 44.49%
# INFO:few-shot:Preprocessing data. 44.67%
# INFO:few-shot:Preprocessing data. 44.85%
# INFO:few-shot:Preprocessing data. 45.22%
# INFO:few-shot:Preprocessing data. 45.40%
# INFO:few-shot:Preprocessing data. 45.59%
# INFO:few-shot:Preprocessing data. 45.96%
# INFO:few-shot:Preprocessing data. 46.14%
# INFO:few-shot:Preprocessing data. 46.32%
# INFO:few-shot:Preprocessing data. 46.69%
# INFO:few-shot:Preprocessing data. 46.88%
# INFO:few-shot:Preprocessing data. 47.06%
# INFO:few-shot:Preprocessing data. 47.24%
# INFO:few-shot:Preprocessing data. 47.43%
# INFO:few-shot:Preprocessing data. 47.61%
# INFO:few-shot:Preprocessing data. 47.79%
# INFO:few-shot:Preprocessing data. 47.98%
# INFO:few-shot:Preprocessing data. 48.16%
# INFO:few-shot:Preprocessing data. 48.35%
# INFO:few-shot:Preprocessing data. 48.53%
# INFO:few-shot:Preprocessing data. 48.71%
# INFO:few-shot:Preprocessing data. 48.90%
# INFO:few-shot:Preprocessing data. 49.08%
# INFO:few-shot:Preprocessing data. 49.26%
# INFO:few-shot:Preprocessing data. 49.45%
# INFO:few-shot:Preprocessing data. 49.63%
# INFO:few-shot:Preprocessing data. 49.82%
# INFO:few-shot:Preprocessing data. 50.18%
# INFO:few-shot:Preprocessing data. 50.37%
# INFO:few-shot:Preprocessing data. 50.55%
# INFO:few-shot:Preprocessing data. 50.74%
# INFO:few-shot:Preprocessing data. 50.92%
# INFO:few-shot:Preprocessing data. 51.10%
# INFO:few-shot:Preprocessing data. 51.29%
# INFO:few-shot:Preprocessing data. 51.47%
# INFO:few-shot:Preprocessing data. 51.65%
# INFO:few-shot:Preprocessing data. 51.84%
# INFO:few-shot:Preprocessing data. 52.02%
# INFO:few-shot:Preprocessing data. 52.21%
# INFO:few-shot:Preprocessing data. 52.39%
# INFO:few-shot:Preprocessing data. 52.57%
# INFO:few-shot:Preprocessing data. 52.76%
# INFO:few-shot:Preprocessing data. 52.94%
# INFO:few-shot:Preprocessing data. 53.12%
# INFO:few-shot:Preprocessing data. 53.31%
# INFO:few-shot:Preprocessing data. 53.49%
# INFO:few-shot:Preprocessing data. 53.86%
# INFO:few-shot:Preprocessing data. 54.04%
# INFO:few-shot:Preprocessing data. 54.41%
# INFO:few-shot:Preprocessing data. 54.60%
# INFO:few-shot:Preprocessing data. 54.78%
# INFO:few-shot:Preprocessing data. 54.96%
# INFO:few-shot:Preprocessing data. 55.15%
# INFO:few-shot:Preprocessing data. 55.51%
# INFO:few-shot:Preprocessing data. 55.70%
# INFO:few-shot:Preprocessing data. 55.88%
# INFO:few-shot:Preprocessing data. 56.25%
# INFO:few-shot:Preprocessing data. 56.43%
# INFO:few-shot:Preprocessing data. 56.62%
# INFO:few-shot:Preprocessing data. 56.80%
# INFO:few-shot:Preprocessing data. 56.99%
# INFO:few-shot:Preprocessing data. 57.17%
# INFO:few-shot:Preprocessing data. 57.35%
# INFO:few-shot:Preprocessing data. 57.54%
# INFO:few-shot:Preprocessing data. 57.72%
# INFO:few-shot:Preprocessing data. 57.90%
# INFO:few-shot:Preprocessing data. 58.09%
# INFO:few-shot:Preprocessing data. 58.27%
# INFO:few-shot:Preprocessing data. 58.46%
# INFO:few-shot:Preprocessing data. 58.64%
# INFO:few-shot:Preprocessing data. 59.01%
# INFO:few-shot:Preprocessing data. 59.19%
# INFO:few-shot:Preprocessing data. 59.38%
# INFO:few-shot:Preprocessing data. 59.56%
# INFO:few-shot:Preprocessing data. 59.93%
# INFO:few-shot:Preprocessing data. 60.11%
# INFO:few-shot:Preprocessing data. 60.29%
# INFO:few-shot:Preprocessing data. 60.48%
# INFO:few-shot:Preprocessing data. 60.66%
# INFO:few-shot:Preprocessing data. 60.85%
# INFO:few-shot:Preprocessing data. 61.03%
# INFO:few-shot:Preprocessing data. 61.21%
# INFO:few-shot:Preprocessing data. 61.40%
# INFO:few-shot:Preprocessing data. 61.58%
# INFO:few-shot:Preprocessing data. 61.76%
# INFO:few-shot:Preprocessing data. 61.95%
# INFO:few-shot:Preprocessing data. 62.13%
# INFO:few-shot:Preprocessing data. 62.32%
# INFO:few-shot:Preprocessing data. 62.68%
# INFO:few-shot:Preprocessing data. 62.87%
# INFO:few-shot:Preprocessing data. 63.05%
# INFO:few-shot:Preprocessing data. 63.24%
# INFO:few-shot:Preprocessing data. 63.42%
# INFO:few-shot:Preprocessing data. 63.79%
# INFO:few-shot:Preprocessing data. 64.15%
# INFO:few-shot:Preprocessing data. 64.34%
# INFO:few-shot:Preprocessing data. 64.52%
# INFO:few-shot:Preprocessing data. 64.71%
# INFO:few-shot:Preprocessing data. 64.89%
# INFO:few-shot:Preprocessing data. 65.07%
# INFO:few-shot:Preprocessing data. 65.26%
# INFO:few-shot:Preprocessing data. 65.44%
# INFO:few-shot:Preprocessing data. 65.62%
# INFO:few-shot:Preprocessing data. 65.81%
# INFO:few-shot:Preprocessing data. 65.99%
# INFO:few-shot:Preprocessing data. 66.36%
# INFO:few-shot:Preprocessing data. 66.73%
# INFO:few-shot:Preprocessing data. 67.10%
# INFO:few-shot:Preprocessing data. 67.28%
# INFO:few-shot:Preprocessing data. 67.65%
# INFO:few-shot:Preprocessing data. 67.83%
# INFO:few-shot:Preprocessing data. 68.01%
# INFO:few-shot:Preprocessing data. 68.38%
# INFO:few-shot:Preprocessing data. 68.75%
# INFO:few-shot:Preprocessing data. 68.93%
# INFO:few-shot:Preprocessing data. 69.12%
# INFO:few-shot:Preprocessing data. 69.30%
# INFO:few-shot:Preprocessing data. 69.49%
# INFO:few-shot:Preprocessing data. 69.67%
# INFO:few-shot:Preprocessing data. 69.85%
# INFO:few-shot:Preprocessing data. 70.22%
# INFO:few-shot:Preprocessing data. 70.40%
# INFO:few-shot:Preprocessing data. 70.59%
# INFO:few-shot:Preprocessing data. 70.77%
# INFO:few-shot:Preprocessing data. 70.96%
# INFO:few-shot:Preprocessing data. 71.14%
# INFO:few-shot:Preprocessing data. 71.32%
# INFO:few-shot:Preprocessing data. 71.51%
# INFO:few-shot:Preprocessing data. 71.69%
# INFO:few-shot:Preprocessing data. 71.88%
# INFO:few-shot:Preprocessing data. 72.06%
# INFO:few-shot:Preprocessing data. 72.24%
# INFO:few-shot:Preprocessing data. 72.43%
# INFO:few-shot:Preprocessing data. 72.61%
# INFO:few-shot:Preprocessing data. 72.79%
# INFO:few-shot:Preprocessing data. 72.98%
# INFO:few-shot:Preprocessing data. 73.16%
# INFO:few-shot:Preprocessing data. 73.35%
# INFO:few-shot:Preprocessing data. 73.53%
# INFO:few-shot:Preprocessing data. 73.71%
# INFO:few-shot:Preprocessing data. 74.08%
# INFO:few-shot:Preprocessing data. 74.26%
# INFO:few-shot:Preprocessing data. 74.45%
# INFO:few-shot:Preprocessing data. 74.63%
# INFO:few-shot:Preprocessing data. 74.82%
# INFO:few-shot:Preprocessing data. 75.00%
# INFO:few-shot:Preprocessing data. 75.18%
# INFO:few-shot:Preprocessing data. 75.37%
# INFO:few-shot:Preprocessing data. 75.55%
# INFO:few-shot:Preprocessing data. 75.74%
# INFO:few-shot:Preprocessing data. 75.92%
# INFO:few-shot:Preprocessing data. 76.10%
# INFO:few-shot:Preprocessing data. 76.29%
# INFO:few-shot:Preprocessing data. 76.47%
# INFO:few-shot:Preprocessing data. 76.65%
# INFO:few-shot:Preprocessing data. 76.84%
# INFO:few-shot:Preprocessing data. 77.02%
# INFO:few-shot:Preprocessing data. 77.21%
# INFO:few-shot:Preprocessing data. 77.39%
# INFO:few-shot:Preprocessing data. 77.57%
# INFO:few-shot:Preprocessing data. 77.76%
# INFO:few-shot:Preprocessing data. 77.94%
# INFO:few-shot:Preprocessing data. 78.12%
# INFO:few-shot:Preprocessing data. 78.31%
# INFO:few-shot:Preprocessing data. 78.68%
# INFO:few-shot:Preprocessing data. 78.86%
# INFO:few-shot:Preprocessing data. 79.04%
# INFO:few-shot:Preprocessing data. 79.23%
# INFO:few-shot:Preprocessing data. 79.41%
# INFO:few-shot:Preprocessing data. 79.60%
# INFO:few-shot:Preprocessing data. 79.78%
# INFO:few-shot:Preprocessing data. 79.96%
# INFO:few-shot:Preprocessing data. 80.15%
# INFO:few-shot:Preprocessing data. 80.33%
# INFO:few-shot:Preprocessing data. 80.51%
# INFO:few-shot:Preprocessing data. 80.88%
# INFO:few-shot:Preprocessing data. 81.07%
# INFO:few-shot:Preprocessing data. 81.25%
# INFO:few-shot:Preprocessing data. 81.43%
# INFO:few-shot:Preprocessing data. 81.62%
# INFO:few-shot:Preprocessing data. 81.80%
# INFO:few-shot:Preprocessing data. 81.99%
# INFO:few-shot:Preprocessing data. 82.17%
# INFO:few-shot:Preprocessing data. 82.35%
# INFO:few-shot:Preprocessing data. 82.54%
# INFO:few-shot:Preprocessing data. 82.72%
# INFO:few-shot:Preprocessing data. 82.90%
# INFO:few-shot:Preprocessing data. 83.27%
# INFO:few-shot:Preprocessing data. 83.46%
# INFO:few-shot:Preprocessing data. 83.64%
# INFO:few-shot:Preprocessing data. 83.82%
# INFO:few-shot:Preprocessing data. 84.19%
# INFO:few-shot:Preprocessing data. 84.56%
# INFO:few-shot:Preprocessing data. 84.74%
# INFO:few-shot:Preprocessing data. 84.93%
# INFO:few-shot:Preprocessing data. 85.11%
# INFO:few-shot:Preprocessing data. 85.29%
# INFO:few-shot:Preprocessing data. 85.48%
# INFO:few-shot:Preprocessing data. 85.66%
# INFO:few-shot:Preprocessing data. 86.03%
# INFO:few-shot:Preprocessing data. 86.21%
# INFO:few-shot:Preprocessing data. 86.58%
# INFO:few-shot:Preprocessing data. 86.95%
# INFO:few-shot:Preprocessing data. 87.13%
# INFO:few-shot:Preprocessing data. 87.50%
# INFO:few-shot:Preprocessing data. 87.87%
# INFO:few-shot:Preprocessing data. 88.24%
# INFO:few-shot:Preprocessing data. 88.42%
# INFO:few-shot:Preprocessing data. 88.79%
# INFO:few-shot:Preprocessing data. 88.97%
# INFO:few-shot:Preprocessing data. 89.34%
# INFO:few-shot:Preprocessing data. 89.71%
# INFO:few-shot:Preprocessing data. 89.89%
# INFO:few-shot:Preprocessing data. 90.26%
# INFO:few-shot:Preprocessing data. 90.44%
# INFO:few-shot:Preprocessing data. 90.62%
# INFO:few-shot:Preprocessing data. 90.81%
# INFO:few-shot:Preprocessing data. 90.99%
# INFO:few-shot:Preprocessing data. 91.18%
# INFO:few-shot:Preprocessing data. 91.36%
# INFO:few-shot:Preprocessing data. 91.54%
# INFO:few-shot:Preprocessing data. 91.91%
# INFO:few-shot:Preprocessing data. 92.28%
# INFO:few-shot:Preprocessing data. 92.46%
# INFO:few-shot:Preprocessing data. 92.65%
# INFO:few-shot:Preprocessing data. 92.83%
# INFO:few-shot:Preprocessing data. 93.01%
# INFO:few-shot:Preprocessing data. 93.20%
# INFO:few-shot:Preprocessing data. 93.38%
# INFO:few-shot:Preprocessing data. 93.57%
# INFO:few-shot:Preprocessing data. 93.93%
# INFO:few-shot:Preprocessing data. 94.12%
# INFO:few-shot:Preprocessing data. 94.30%
# INFO:few-shot:Preprocessing data. 94.49%
# INFO:few-shot:Preprocessing data. 94.85%
# INFO:few-shot:Preprocessing data. 95.04%
# INFO:few-shot:Preprocessing data. 95.22%
# INFO:few-shot:Preprocessing data. 95.40%
# INFO:few-shot:Preprocessing data. 95.59%
# INFO:few-shot:Preprocessing data. 95.77%
# INFO:few-shot:Preprocessing data. 95.96%
# INFO:few-shot:Preprocessing data. 96.14%
# INFO:few-shot:Preprocessing data. 96.32%
# INFO:few-shot:Preprocessing data. 96.51%
# INFO:few-shot:Preprocessing data. 96.69%
# INFO:few-shot:Preprocessing data. 96.88%
# INFO:few-shot:Preprocessing data. 97.06%
# INFO:few-shot:Preprocessing data. 97.24%
# INFO:few-shot:Preprocessing data. 97.43%
# INFO:few-shot:Preprocessing data. 97.61%
# INFO:few-shot:Preprocessing data. 97.79%
# INFO:few-shot:Preprocessing data. 97.98%
# INFO:few-shot:Preprocessing data. 98.16%
# INFO:few-shot:Preprocessing data. 98.53%
# INFO:few-shot:Preprocessing data. 98.71%
# INFO:few-shot:Preprocessing data. 98.90%
# INFO:few-shot:Preprocessing data. 99.26%
# INFO:few-shot:Preprocessing data. 99.45%
# INFO:few-shot:Preprocessing data. 99.63%
# INFO:few-shot:64 artists don't have K+K'=11 songs. Using 480 artists

# %%
eps
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     393                             if callable(meth):
#     394                                 return meth(obj, self, cycle)
# --> 395             return _default_pprint(obj, self, cycle)
#     396         finally:
#     397             self.end_group()
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in _default_pprint(obj, p, cycle)
#     508     if _safe_getattr(klass, '__repr__', None) is not object.__repr__:
#     509         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 510         _repr_pprint(obj, p, cycle)
#     511         return
#     512     p.begin_group(1, '<')
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     699     """A pprint that just redirects to the normal repr function."""
#     700     # Find newlines and replace them with p.break_()
# --> 701     output = repr(obj)
#     702     for idx,output_line in enumerate(output.splitlines()):
#     703         if idx:
#
# ~/UBC/cpsc_532L/project/src/episode.py in __repr__(self)
#      52
#      53     def __repr__(self):
# ---> 54         return 'EpisodeSampler("%s", "%s")' % (self.root, self.split)
#      55
#      56     def get_episode(self):
#
# AttributeError: 'EpisodeSampler' object has no attribute 'root'
